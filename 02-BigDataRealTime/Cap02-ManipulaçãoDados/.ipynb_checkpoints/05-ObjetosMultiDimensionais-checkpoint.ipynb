# %% [markdown]
# # Estruturas de Dados em Pandas
#
# ### pandas.Series() - 1 Dimensão
# ### pandas.DataFrame() - 2 Dimensões
# ### pandas.Panel() - 3 Dimensões
# ### numpy.ndarray() - x Dimensões

# %% [markdown]
# # Panel

# %%
import pandas as pd
import numpy as np
import warnings
# warnings.filterwarnings("ignore")

# %%
data = np.random.randint(1, 10, (5, 3, 2))

# %%
painel = pd.Panel.to_frame(
    data, 
    items = ['item {}'.format(i) for i in range (1,6)],
    major_axis = [2015, 2016, 2017],
    minor_axis = ['US', 'UK']
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-9225f42473cc> in <module>
# ----> 1 painel = pd.Panel.to_frame(
#       2     data,
#       3     items = ['item {}'.format(i) for i in range (1,6)],
#       4     major_axis = [2015, 2016, 2017],
#       5     minor_axis = ['US', 'UK']
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'Panel'

# %%
data = data.reshape(5, 6).T

# %%
df = pd.DataFrame(
    data = data,
    index=pd.MultiIndex.from_product([[2015,2016,2017], ['US','UK']]),
    columns=['item {}'.format(i) for i in range(1,6)]
)

# %%
df
# Out:
#          item 1  item 2  item 3  item 4  item 5
# 2015 US       8       1       8       6       1
#      UK       7       2       6       6       1
# 2016 US       6       4       1       4       5
#      UK       5       8       5       7       2
# 2017 US       5       8       6       8       6
#      UK       1       8       5       9       5

# %% [markdown]
# # Criando um Data Frame a partir de um dicionário

# %%
USData = pd.DataFrame(
    np.array([[249.62, 8900],
             [282.16,12680],
              [309.35,14940]
             ]),
    columns= ['População(M)', 'PIB($B)'],
    index = [1995, 2005, 2015]
)

# %%
USData
# Out:
#       População(M)  PIB($B)
# 1995        249.62   8900.0
# 2005        282.16  12680.0
# 2015        309.35  14940.0

# %%
ChinaData = pd.DataFrame(
    np.array([[1133.68, 390.28],
             [1266.83,1198.48],
              [1339.72,9923.47]
             ]),
    columns= ['População(M)', 'PIB($B)'],
    index = [1995, 2005, 2015]
)

# %%
ChinaData
# Out:
#       População(M)  PIB($B)
# 1995       1133.68   390.28
# 2005       1266.83  1198.48
# 2015       1339.72  9923.47

# %%
US_ChinaData = {'US': USData,
               'China': ChinaData}

# %%
US_ChinaData
# Out:
# {'US':       População(M)  PIB($B)
#  1995        249.62   8900.0
#  2005        282.16  12680.0
#  2015        309.35  14940.0,
#  'China':       População(M)  PIB($B)
#  1995       1133.68   390.28
#  2005       1266.83  1198.48
#  2015       1339.72  9923.47}

# %%
# Converte para painel, que não tem na últma Versão
pd.Panel(US_ChinaData)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-1abecd0b5da7> in <module>
#       1 # Converte para painel, que não tem na últma Versão
# ----> 2 pd.Panel(US_ChinaData)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'Panel'

# %% [markdown]
# # Convertendo DataFrame para Panel

# %%
mIdx = pd.MultiIndex(levels = [['US', 'China'], [1995,2005,2015]],
                    
                    codes = [[1,1,1,0,0,0], [0,1,2,0,1,2]]) # No exemplo mostrava como labels

# %%
mIdx
# Out:
# MultiIndex([('China', 1995),
#             ('China', 2005),
#             ('China', 2015),
#             (   'US', 1995),
#             (   'US', 2005),
#             (   'US', 2015)],
#            )

# %%
ChinaUSDF = pd.DataFrame({'População(M)' : [1133.68, 1266.93, 1339.72, 249.62, 282.16, 309.35],
                         'PIB($B)' : [390.28, 1198.48, 6988.47, 8900, 12680, 14940]},
                        index=mIdx)

# %%
ChinaUSDF
# Out:
#             População(M)   PIB($B)
# China 1995       1133.68    390.28
#       2005       1266.93   1198.48
#       2015       1339.72   6988.47
# US    1995        249.62   8900.00
#       2005        282.16  12680.00
#       2015        309.35  14940.00

# %%
# !pip install xarray
# Out:
# Requirement already satisfied: xarray in /home/carlos-vitorino/anaconda3/lib/python3.8/site-packages (0.18.2)
# Requirement already satisfied: pandas>=1.0 in /home/carlos-vitorino/anaconda3/lib/python3.8/site-packages (from xarray) (1.2.4)
# Requirement already satisfied: setuptools>=40.4 in /home/carlos-vitorino/anaconda3/lib/python3.8/site-packages (from xarray) (52.0.0.post20210125)
# Requirement already satisfied: numpy>=1.17 in /home/carlos-vitorino/anaconda3/lib/python3.8/site-packages (from xarray) (1.20.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/carlos-vitorino/anaconda3/lib/python3.8/site-packages (from pandas>=1.0->xarray) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /home/carlos-vitorino/anaconda3/lib/python3.8/site-packages (from pandas>=1.0->xarray) (2021.1)
# Requirement already satisfied: six>=1.5 in /home/carlos-vitorino/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=1.0->xarray) (1.16.0)

# %%
# ChinaUSDF.to_panel()
ChinaUSDF.to_xarray()
# Out:
# <xarray.Dataset>
# Dimensions:       (level_0: 2, level_1: 3)
# Coordinates:
#   * level_0       (level_0) object 'US' 'China'
#   * level_1       (level_1) int64 1995 2005 2015
# Data variables:
#     População(M)  (level_0, level_1) float64 249.6 282.2 ... 1.267e+03 1.34e+03
#     PIB($B)       (level_0, level_1) float64 8.9e+03 1.268e+04 ... 6.988e+03

# %% [markdown]
# # Fim
