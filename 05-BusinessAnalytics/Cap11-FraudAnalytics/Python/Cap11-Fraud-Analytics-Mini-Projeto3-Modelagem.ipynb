# %% [markdown]
# # <font color='blue'>Data Science Academy</font>
# # <font color='blue'>Business Analytics</font>
#
# # <font color='blue'>Capítulo 11 - Fraud Analytics</font>
# ## <font color='blue'>Mini-Projeto 3</font>
# ### <font color='blue'>Data Quality Report e Detecção de Fraudes em Transações Imobiliárias</font>

# %% [markdown]
# ## Etapa 2 - Modelagem
#
# - Existem diversas técnicas para análise e detecção de fraude.
# - Aplicaremos aqui uma abordagem via aprendizado **não supervisionado** criando scores (pontuações) de fraude para cada transação imobiliária.
# - Serão criados 2 scores com técnicas diferentes de Machine Learning e depois vamos unir os scores e apresentar o score final.
# - A Engenharia de Atributos será parte fundamental do processo.
# - Este trabalho tem nível intermediário de dificuldade.

# %% [markdown]
# ![title](imagens/mini-projeto3.png)

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.8.11

# %% [markdown]
# ## Instalando e Carregando os Pacotes

# %%
# Para atualizar um pacote, execute o comando abaixo no terminal ou prompt de comando:
# pip install -U nome_pacote

# Para instalar a versão exata de um pacote, execute o comando abaixo no terminal ou prompt de comando:
# !pip install nome_pacote==versão_desejada

# Depois de instalar ou atualizar o pacote, reinicie o jupyter notebook.

# Instala o pacote watermark. 
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.
# !pip install -q -U watermark

# %%
# Imports
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import warnings
warnings.filterwarnings("ignore")

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Data Science Academy" --iversions
# Out:
# Author: Data Science Academy
#
# numpy     : 1.20.3
# pandas    : 1.3.2
# seaborn   : 0.11.2
# matplotlib: 3.4.2

# %% [markdown]
# ## Carregando os Dados

# %%
# Carrega os dados
df = pd.read_csv('dados/dataset.csv')

# %%
# Shape
df.shape
# Out:
# (1070994, 32)

# %%
# Visualiza amostra dos dados
df.head()
# Out:
#    RECORD        BBLE  B  BLOCK  LOT EASEMENT                  OWNER BLDGCL  \
# 0       1  1000010101  1      1  101      NaN  U S GOVT LAND & BLDGS     P7
# 1       2  1000010201  1      1  201      NaN  U S GOVT LAND & BLDGS     Z9
# 2       3  1000020001  1      2    1      NaN  DEPT OF GENERAL SERVI     Y7
# 3       4  1000020023  1      2   23      NaN  DEPARTMENT OF BUSINES     T2
# 4       5  1000030001  1      3    1      NaN   PARKS AND RECREATION     Q1
#
#   TAXCLASS  LTFRONT  LTDEPTH  EXT  STORIES      FULLVAL       AVLAND  \
# 0        4      500     1046  NaN      NaN   21400000.0    4225500.0
# 1        4       27        0  NaN      NaN  193800000.0   14310000.0
# 2        4      709      564    E      3.0  104686000.0   39008700.0
# 3        4      793      551  NaN      2.0   39200000.0   15255000.0
# 4        4      323     1260  NaN      1.0  272300000.0  121050000.0
#
#          AVTOT       EXLAND        EXTOT   EXCD1            STADDR      ZIP  \
# 0    9630000.0    4225500.0    9630000.0  4600.0  1 LIBERTY ISLAND  10004.0
# 1   87210000.0   14310000.0   87210000.0  4600.0    1 ELLIS ISLAND  10004.0
# 2   47108700.0   39008700.0   47108700.0  2191.0   MARGINAL STREET  10004.0
# 3   17640000.0   15255000.0   17640000.0  2191.0            PIER 6  10004.0
# 4  122535000.0  121050000.0  122535000.0  2231.0      BATTERY PARK  10004.0
#
#   EXMPTCL  BLDFRONT  BLDDEPTH      AVLAND2       AVTOT2      EXLAND2  \
# 0      X3         0         0    3775500.0    8613000.0    3775500.0
# 1      X3         0         0   11111400.0   80690400.0   11111400.0
# 2      X1       709       564   32321790.0   40179510.0   32321790.0
# 3      X1        85       551   13644000.0   15750000.0   13644000.0
# 4      X1        89        57  106348680.0  107758350.0  106348680.0
#
#         EXTOT2  EXCD2 PERIOD     YEAR VALTYPE
# 0    8613000.0    NaN  FINAL  2010/11   AC-TR
# 1   80690400.0    NaN  FINAL  2010/11   AC-TR
# 2   40179510.0    NaN  FINAL  2010/11   AC-TR
# 3   15750000.0    NaN  FINAL  2010/11   AC-TR
# 4  107758350.0    NaN  FINAL  2010/11   AC-TR

# %%
# Colunas
df.columns
# Out:
# Index(['RECORD', 'BBLE', 'B', 'BLOCK', 'LOT', 'EASEMENT', 'OWNER', 'BLDGCL',
#        'TAXCLASS', 'LTFRONT', 'LTDEPTH', 'EXT', 'STORIES', 'FULLVAL', 'AVLAND',
#        'AVTOT', 'EXLAND', 'EXTOT', 'EXCD1', 'STADDR', 'ZIP', 'EXMPTCL',
#        'BLDFRONT', 'BLDDEPTH', 'AVLAND2', 'AVTOT2', 'EXLAND2', 'EXTOT2',
#        'EXCD2', 'PERIOD', 'YEAR', 'VALTYPE'],
#       dtype='object')

# %%
# Resumo
print("Linhas: ", df.shape[0])
print("Colunas: ", df.shape[1])
print("\nVariáveis: \n", df.columns.tolist())
print("\nValores Ausentes: \n" , df.isnull().sum())
print("\nValores Únicos: \n", df.nunique())
# Out:
# Linhas:  1070994
# Colunas:  32
#
# Variáveis:
#  ['RECORD', 'BBLE', 'B', 'BLOCK', 'LOT', 'EASEMENT', 'OWNER', 'BLDGCL', 'TAXCLASS', 'LTFRONT', 'LTDEPTH', 'EXT', 'STORIES', 'FULLVAL', 'AVLAND', 'AVTOT', 'EXLAND', 'EXTOT', 'EXCD1', 'STADDR', 'ZIP', 'EXMPTCL', 'BLDFRONT', 'BLDDEPTH', 'AVLAND2', 'AVTOT2', 'EXLAND2', 'EXTOT2', 'EXCD2', 'PERIOD', 'YEAR', 'VALTYPE']
#
# Valores Ausentes:
#  RECORD            0
# BBLE              0
# B                 0
# BLOCK             0
# LOT               0
# EASEMENT    1066358
# OWNER         31745
# BLDGCL            0
# TAXCLASS          0
# LTFRONT           0
# LTDEPTH           0
# EXT          716689
# STORIES       56264
# FULLVAL           0
# AVLAND            0
# AVTOT             0
# EXLAND            0
# EXTOT             0
# EXCD1        432506
# STADDR          676
# ZIP           29890
# EXMPTCL     1055415
# BLDFRONT          0
# BLDDEPTH          0
# AVLAND2      788268
# AVTOT2       788262
# EXLAND2      983545
# EXTOT2       940166
# EXCD2        978046
# PERIOD            0
# YEAR              0
# VALTYPE           0
# dtype: int64
#
# Valores Únicos:
#  RECORD      1070994
# BBLE        1070994
# B                 5
# BLOCK         13984
# LOT            6366
# EASEMENT         12
# OWNER        863346
# BLDGCL          200
# TAXCLASS         11
# LTFRONT        1297
# LTDEPTH        1370
# EXT               3
# STORIES         111
# FULLVAL      109324
# AVLAND        70921
# AVTOT        112914
# EXLAND        33419
# EXTOT         64255
# EXCD1           129
# STADDR       839280
# ZIP             196
# EXMPTCL          14
# BLDFRONT        612
# BLDDEPTH        621
# AVLAND2       58591
# AVTOT2       111360
# EXLAND2       22195
# EXTOT2        48348
# EXCD2            60
# PERIOD            1
# YEAR              1
# VALTYPE           1
# dtype: int64

# %%
# Vamos trabalhar com uma cópia do dataframe
df_temp = df.copy()

# %% [markdown]
# ## Limpeza e Transformação dos Dados

# %% [markdown]
# ### Limpando Valores Ausentes da Variável ZIP

# %%
# Contagem de valores ausentes
df_temp['ZIP'].isna().sum()
# Out:
# 29890

# %%
# Vamos calcular o valor da variável zip que aparece com maior frequência (calcular a moda)
# Se não houver nenhum valor de moda, substitua por 1
def calcula_moda(x):
    m = pd.Series.mode(x)
    if m.empty:
        x = np.array(range(1,11))
        return x[0]
    else:
        return m.values[0]

# %%
# Definindo a função de contagem para calcular a frequência do valor da moda de cada grupo (que vamos definir)
def contagem(x):
    return x.value_counts().head(1)

# %%
# Agrupando valores pela variável 'B' e 'BLOCK' e usando as duas funções acima para criar dataframe auxiliar
# Teremos o valor da moda da variável ZIP para cada grupo com registros com as variáveis B e Block
df_zip_group = df_temp.groupby(['B','BLOCK'])['ZIP'].agg(ZIP = calcula_moda, Count = contagem).reset_index()

# %%
# Verificando os 25 primeiros registros
df_zip_group.head(25)
# Out:
#     B  BLOCK      ZIP Count
# 0   1      1  10004.0     2
# 1   1      2  10004.0     2
# 2   1      3  10004.0     4
# 3   1      4  10004.0    53
# 4   1      5  10004.0     9
# 5   1      6  10004.0     2
# 6   1      7  10004.0    15
# 7   1      8  10004.0     6
# 8   1      9  10004.0     4
# 9   1     10  10004.0     8
# 10  1     11  10004.0    16
# 11  1     12  10004.0     2
# 12  1     13  10004.0     4
# 13  1     15  10280.0   285
# 14  1     16  10280.0  3252
# 15  1     17  10006.0    19
# 16  1     18  10006.0   455
# 17  1     19  10006.0     7
# 18  1     20  10006.0     6
# 19  1     21  10006.0     3
# 20  1     22  10004.0     5
# 21  1     23  10004.0     3
# 22  1     24  10004.0   172
# 23  1     25  10004.0   329
# 24  1     26  10005.0   403

# %%
# Para os grupos sem valor de moda, comparamos a frequência do grupo, um grupo abaixo e um grupo acima
# Inserimos o valor do ZIP do grupo com maior frequência
for i in range(len(df_zip_group)):
    if (df_zip_group.loc[i,'ZIP'] == 1):
        if df_zip_group.loc[i - 1,'Count'] > df_zip_group.loc[i + 1,'Count']:
            val = df_zip_group.loc[i - 1,'ZIP']
        else:
            val = df_zip_group.loc[i + 1,'ZIP']
        df_zip_group.loc[i,'ZIP'] = val

# %%
# Verificando os 25 primeiros registros
df_zip_group.head(25)
# Out:
#     B  BLOCK      ZIP Count
# 0   1      1  10004.0     2
# 1   1      2  10004.0     2
# 2   1      3  10004.0     4
# 3   1      4  10004.0    53
# 4   1      5  10004.0     9
# 5   1      6  10004.0     2
# 6   1      7  10004.0    15
# 7   1      8  10004.0     6
# 8   1      9  10004.0     4
# 9   1     10  10004.0     8
# 10  1     11  10004.0    16
# 11  1     12  10004.0     2
# 12  1     13  10004.0     4
# 13  1     15  10280.0   285
# 14  1     16  10280.0  3252
# 15  1     17  10006.0    19
# 16  1     18  10006.0   455
# 17  1     19  10006.0     7
# 18  1     20  10006.0     6
# 19  1     21  10006.0     3
# 20  1     22  10004.0     5
# 21  1     23  10004.0     3
# 22  1     24  10004.0   172
# 23  1     25  10004.0   329
# 24  1     26  10005.0   403

# %%
# Definindo a função que preenche os registros com valor ZIP ausente por meio do dataframe auxiliar
def preenche_moda(x):
    if pd.isnull(x['ZIP']):
        return df_zip_group[(df_zip_group['B'] == x['B']) & (df_zip_group['BLOCK'] == x['BLOCK'])]['ZIP'].values[0]
    else:
        return x['ZIP']

# %%
# Usando a função para preencher os valores ZIP ausentes
df_temp['ZIP'] = df_temp.apply(preenche_moda, axis = 1)

# %%
# Verificando se há algum valor ZIP restante com valor NA
df_temp['ZIP'].isna().sum()
# Out:
# 0

# %%
# Verificando manualmente uma das ocorrências para checar se a fórmula funcionou corretamente
df_temp[(df_temp['B']==1) & (df_temp['BLOCK']==36)]['ZIP']
# Out:
# 6092    10005.0
# 6093    10005.0
# 6094    10005.0
# 6095    10005.0
# Name: ZIP, dtype: float64

# %%
# Visualiza
df_temp.head()
# Out:
#    RECORD        BBLE  B  BLOCK  LOT EASEMENT                  OWNER BLDGCL  \
# 0       1  1000010101  1      1  101      NaN  U S GOVT LAND & BLDGS     P7
# 1       2  1000010201  1      1  201      NaN  U S GOVT LAND & BLDGS     Z9
# 2       3  1000020001  1      2    1      NaN  DEPT OF GENERAL SERVI     Y7
# 3       4  1000020023  1      2   23      NaN  DEPARTMENT OF BUSINES     T2
# 4       5  1000030001  1      3    1      NaN   PARKS AND RECREATION     Q1
#
#   TAXCLASS  LTFRONT  LTDEPTH  EXT  STORIES      FULLVAL       AVLAND  \
# 0        4      500     1046  NaN      NaN   21400000.0    4225500.0
# 1        4       27        0  NaN      NaN  193800000.0   14310000.0
# 2        4      709      564    E      3.0  104686000.0   39008700.0
# 3        4      793      551  NaN      2.0   39200000.0   15255000.0
# 4        4      323     1260  NaN      1.0  272300000.0  121050000.0
#
#          AVTOT       EXLAND        EXTOT   EXCD1            STADDR      ZIP  \
# 0    9630000.0    4225500.0    9630000.0  4600.0  1 LIBERTY ISLAND  10004.0
# 1   87210000.0   14310000.0   87210000.0  4600.0    1 ELLIS ISLAND  10004.0
# 2   47108700.0   39008700.0   47108700.0  2191.0   MARGINAL STREET  10004.0
# 3   17640000.0   15255000.0   17640000.0  2191.0            PIER 6  10004.0
# 4  122535000.0  121050000.0  122535000.0  2231.0      BATTERY PARK  10004.0
#
#   EXMPTCL  BLDFRONT  BLDDEPTH      AVLAND2       AVTOT2      EXLAND2  \
# 0      X3         0         0    3775500.0    8613000.0    3775500.0
# 1      X3         0         0   11111400.0   80690400.0   11111400.0
# 2      X1       709       564   32321790.0   40179510.0   32321790.0
# 3      X1        85       551   13644000.0   15750000.0   13644000.0
# 4      X1        89        57  106348680.0  107758350.0  106348680.0
#
#         EXTOT2  EXCD2 PERIOD     YEAR VALTYPE
# 0    8613000.0    NaN  FINAL  2010/11   AC-TR
# 1   80690400.0    NaN  FINAL  2010/11   AC-TR
# 2   40179510.0    NaN  FINAL  2010/11   AC-TR
# 3   15750000.0    NaN  FINAL  2010/11   AC-TR
# 4  107758350.0    NaN  FINAL  2010/11   AC-TR

# %%
# Vamos salvar o dataframe resultante em disco
df_temp.to_csv('dados/dataset_zip_limpo.csv')

# %%
df_temp['ZIP'] = df_temp['ZIP'].astype(int).astype(str)

# %%
# Cria cópia da estrutura do dataframe
df_temp2 = df_temp.copy()

# %%
# Carrega os dados do disco
df_temp2 = pd.read_csv('dados/dataset_zip_limpo.csv')

# %% [markdown]
# ### Limpando Valores Ausentes das Variáveis:
#
# FULLVAL, AVLAND, AVTOT, BLDFRONT, BLDDEPTH, LTFRONT e LTDEPTH

# %%
# Substituindo valores vazios por valores NaN para garantir que a função fillna funcione nas etapas posteriores
df_temp2.replace(0, np.nan, inplace = True)

# %%
# Definindo a lista de variáveis a serem preenchidas
list_fill = ['FULLVAL', 'AVLAND', 'AVTOT', 'BLDFRONT', 'BLDDEPTH', 'LTFRONT', 'LTDEPTH']

# %%
# Contando o número de valores NA para cada uma das variáveis
for i in list_fill:
    print(i, "--> Número de valores ausentes:", df_temp2[i].isna().sum())
# Out:
# FULLVAL --> Número de valores ausentes: 13007
# AVLAND --> Número de valores ausentes: 13009
# AVTOT --> Número de valores ausentes: 13007
# BLDFRONT --> Número de valores ausentes: 228815
# BLDDEPTH --> Número de valores ausentes: 228853
# LTFRONT --> Número de valores ausentes: 169108
# LTDEPTH --> Número de valores ausentes: 170128

# %%
# Preenchendo os registros vazios com a mediana do grupo ZIP e BLDGCL se o tamanho do grupo for maior ou igual a 5
for i in list_fill:
    df_temp2[i] = df_temp2.groupby(['ZIP','BLDGCL'])[i].apply(lambda x: x.fillna(x.median()) if len(x) >= 5 else x)

# %%
# Contando o número de valores NA para cada uma das variáveis
for i in list_fill:
    print(i, "--> Número de valores ausentes:", df_temp2[i].isna().sum())
# Out:
# FULLVAL --> Número de valores ausentes: 10294
# AVLAND --> Número de valores ausentes: 10294
# AVTOT --> Número de valores ausentes: 10294
# BLDFRONT --> Número de valores ausentes: 75202
# BLDDEPTH --> Número de valores ausentes: 75218
# LTFRONT --> Número de valores ausentes: 16025
# LTDEPTH --> Número de valores ausentes: 17764

# %%
# Preenchendo os registros vazios com a mediana do grupo ZIP e TAXCLASS se o tamanho do grupo for maior ou igual a 5
for i in list_fill:
    df_temp2[i] = df_temp2.groupby(['ZIP','TAXCLASS'])[i].apply(lambda x: x.fillna(x.median()) if len(x) >= 5 else x)

# %%
# Contando o número de valores NA para cada uma das variáveis
for i in list_fill:
    print(i, "--> Número de valores ausentes:", df_temp2[i].isna().sum())
# Out:
# FULLVAL --> Número de valores ausentes: 3915
# AVLAND --> Número de valores ausentes: 3915
# AVTOT --> Número de valores ausentes: 3915
# BLDFRONT --> Número de valores ausentes: 31226
# BLDDEPTH --> Número de valores ausentes: 31130
# LTFRONT --> Número de valores ausentes: 3092
# LTDEPTH --> Número de valores ausentes: 3146

# %%
# Preenchendo os registros ausentes com a mediana do grupo B e TAXCLASS se o tamanho do grupo for maior ou igual a 5
for i in list_fill:
    df_temp2[i] = df_temp2.groupby(['B','TAXCLASS'])[i].apply(lambda x: x.fillna(x.median()) if len(x) >= 5 else x)

# %%
# Contando o número de valores NA para cada uma das variáveis
for i in list_fill:
    print(i, "--> Número de valores ausentes:", df_temp2[i].isna().sum())
# Out:
# FULLVAL --> Número de valores ausentes: 678
# AVLAND --> Número de valores ausentes: 678
# AVTOT --> Número de valores ausentes: 678
# BLDFRONT --> Número de valores ausentes: 22317
# BLDDEPTH --> Número de valores ausentes: 18831
# LTFRONT --> Número de valores ausentes: 2
# LTDEPTH --> Número de valores ausentes: 2

# %%
# Preenchendo os registros ausentes com a mediana do grupo B se o tamanho do grupo for maior ou igual a 5
for i in list_fill:
    df_temp2[i] = df_temp2.groupby(['B'])[i].apply(lambda x: x.fillna(x.median()) if len(x) >= 5 else x)

# %%
for i in list_fill:
    print(i, "--> Número de valores ausentes:", df_temp2[i].isna().sum())
# Out:
# FULLVAL --> Número de valores ausentes: 0
# AVLAND --> Número de valores ausentes: 0
# AVTOT --> Número de valores ausentes: 0
# BLDFRONT --> Número de valores ausentes: 0
# BLDDEPTH --> Número de valores ausentes: 0
# LTFRONT --> Número de valores ausentes: 0
# LTDEPTH --> Número de valores ausentes: 0

# %% [markdown]
# ### Limpando Valores Ausentes da Variável STORIES

# %%
# Checa valores ausentes
print('STORIES', "--> Número de valores ausentes:", df_temp2['STORIES'].isna().sum())
# Out:
# STORIES --> Número de valores ausentes: 56264

# %%
# Imputação da mediana com base nos grupos de ZIP e BLDGCL
df_temp2['STORIES'] = df_temp2.groupby(['ZIP','BLDGCL'])['STORIES'].apply(lambda x: x.fillna(x.median()) if len(x) >= 5 else x)

# %%
# Checa valores ausentes
print('STORIES', "--> Número de valores ausentes:", df_temp2['STORIES'].isna().sum())
# Out:
# STORIES --> Número de valores ausentes: 42102

# %%
# Imputação da mediana com base nos grupos de BLDGCL e STORIES
df_temp2['STORIES'] = df_temp2.groupby(['BLDGCL'])['STORIES'].apply(lambda x: x.fillna(x.median()) if len(x) >= 5 else x)

# %%
# Checa valores ausentes
print('STORIES', "--> Número de valores ausentes:", df_temp2['STORIES'].isna().sum())
# Out:
# STORIES --> Número de valores ausentes: 4280

# %%
# Imputação da mediana com base nos grupos de TAXCLASS e STORIES
df_temp2['STORIES'] = df_temp2.groupby(['TAXCLASS'])['STORIES'].apply(lambda x: x.fillna(x.median()) if len(x) >= 5 else x)

# %%
# Checa valores ausentes
print('STORIES', "--> Número de valores ausentes:", df_temp2['STORIES'].isna().sum())
# Out:
# STORIES --> Número de valores ausentes: 0

# %%
# Salvando resultado em disco
df_temp2.to_csv('dados/dataset_variaveis_limpo.csv')

# %% [markdown]
# ## Engenharia de Atributos
#
# Vamos criar algumas variáveis a partir de operações com as variáveis existentes.

# %%
# Cópia do dataframe
df_proc = df_temp2.copy()

# %%
# LTFRONT * LTDEPTH
df_proc['AREA1'] = df_proc['LTFRONT'] * df_proc['LTDEPTH']

# %%
# Visualiza amostra
df_proc[['AREA1', 'LTFRONT', 'LTDEPTH']].head()
# Out:
#       AREA1  LTFRONT  LTDEPTH
# 0  523000.0    500.0   1046.0
# 1    9585.0     27.0    355.0
# 2  399876.0    709.0    564.0
# 3  436943.0    793.0    551.0
# 4  406980.0    323.0   1260.0

# %%
# BLDFRONT * BLDDEPTH
df_proc['AREA2'] = df_proc['BLDFRONT'] * df_proc['BLDDEPTH']

# %%
# Visualiza amostra
df_proc[['AREA2', 'BLDFRONT', 'BLDDEPTH']].head()
# Out:
#       AREA2  BLDFRONT  BLDDEPTH
# 0  121476.0     382.0     318.0
# 1  121476.0     382.0     318.0
# 2  399876.0     709.0     564.0
# 3   46835.0      85.0     551.0
# 4    5073.0      89.0      57.0

# %%
# AREA2 * STORIES
df_proc['AREA3'] = df_proc['AREA2'] * df_proc['STORIES']

# %%
# Visualiza amostra
df_proc[['AREA2', 'STORIES', 'AREA3']].head()
# Out:
#       AREA2  STORIES      AREA3
# 0  121476.0      4.0   485904.0
# 1  121476.0      1.0   121476.0
# 2  399876.0      3.0  1199628.0
# 3   46835.0      2.0    93670.0
# 4    5073.0      1.0     5073.0

# %%
# Dividindo FULLVAL, AVLAND e AVTOT pelas variáveis recém criadas AREA1, AREA2 e AREA3 para gerar um índice
k = 1
for i in ['FULLVAL', 'AVLAND', 'AVTOT']:
    for j in ['AREA1', 'AREA2', 'AREA3']:
        indice_area = 'ind' + str(k)
        df_proc[indice_area] = df_proc[i] / df_proc[j]
        print(indice_area + ' é a combinação feita entre:', i, j)
        k += 1
# Out:
# ind1 é a combinação feita entre: FULLVAL AREA1
# ind2 é a combinação feita entre: FULLVAL AREA2
# ind3 é a combinação feita entre: FULLVAL AREA3
# ind4 é a combinação feita entre: AVLAND AREA1
# ind5 é a combinação feita entre: AVLAND AREA2
# ind6 é a combinação feita entre: AVLAND AREA3
# ind7 é a combinação feita entre: AVTOT AREA1
# ind8 é a combinação feita entre: AVTOT AREA2
# ind9 é a combinação feita entre: AVTOT AREA3

# %%
# Visualiza amostra
df_proc.head()
# Out:
#    Unnamed: 0  RECORD        BBLE  B  BLOCK  LOT EASEMENT  \
# 0         NaN       1  1000010101  1      1  101      NaN
# 1         1.0       2  1000010201  1      1  201      NaN
# 2         2.0       3  1000020001  1      2    1      NaN
# 3         3.0       4  1000020023  1      2   23      NaN
# 4         4.0       5  1000030001  1      3    1      NaN
#
#                    OWNER BLDGCL TAXCLASS  LTFRONT  LTDEPTH  EXT  STORIES  \
# 0  U S GOVT LAND & BLDGS     P7        4    500.0   1046.0  NaN      4.0
# 1  U S GOVT LAND & BLDGS     Z9        4     27.0    355.0  NaN      1.0
# 2  DEPT OF GENERAL SERVI     Y7        4    709.0    564.0    E      3.0
# 3  DEPARTMENT OF BUSINES     T2        4    793.0    551.0  NaN      2.0
# 4   PARKS AND RECREATION     Q1        4    323.0   1260.0  NaN      1.0
#
#        FULLVAL       AVLAND        AVTOT       EXLAND        EXTOT   EXCD1  \
# 0   21400000.0    4225500.0    9630000.0    4225500.0    9630000.0  4600.0
# 1  193800000.0   14310000.0   87210000.0   14310000.0   87210000.0  4600.0
# 2  104686000.0   39008700.0   47108700.0   39008700.0   47108700.0  2191.0
# 3   39200000.0   15255000.0   17640000.0   15255000.0   17640000.0  2191.0
# 4  272300000.0  121050000.0  122535000.0  121050000.0  122535000.0  2231.0
#
#              STADDR      ZIP EXMPTCL  BLDFRONT  BLDDEPTH      AVLAND2  \
# 0  1 LIBERTY ISLAND  10004.0      X3     382.0     318.0    3775500.0
# 1    1 ELLIS ISLAND  10004.0      X3     382.0     318.0   11111400.0
# 2   MARGINAL STREET  10004.0      X1     709.0     564.0   32321790.0
# 3            PIER 6  10004.0      X1      85.0     551.0   13644000.0
# 4      BATTERY PARK  10004.0      X1      89.0      57.0  106348680.0
#
#         AVTOT2      EXLAND2       EXTOT2  EXCD2 PERIOD     YEAR VALTYPE  \
# 0    8613000.0    3775500.0    8613000.0    NaN  FINAL  2010/11   AC-TR
# 1   80690400.0   11111400.0   80690400.0    NaN  FINAL  2010/11   AC-TR
# 2   40179510.0   32321790.0   40179510.0    NaN  FINAL  2010/11   AC-TR
# 3   15750000.0   13644000.0   15750000.0    NaN  FINAL  2010/11   AC-TR
# 4  107758350.0  106348680.0  107758350.0    NaN  FINAL  2010/11   AC-TR
#
#       AREA1     AREA2      AREA3          ind1          ind2          ind3  \
# 0  523000.0  121476.0   485904.0     40.917782    176.166486     44.041621
# 1    9585.0  121476.0   121476.0  20219.092332   1595.376865   1595.376865
# 2  399876.0  399876.0  1199628.0    261.796157    261.796157     87.265386
# 3  436943.0   46835.0    93670.0     89.714219    836.980890    418.490445
# 4  406980.0    5073.0     5073.0    669.074647  53676.325646  53676.325646
#
#           ind4          ind5          ind6         ind7          ind8  \
# 0     8.079350     34.784649      8.696162    18.413002     79.274919
# 1  1492.957746    117.801047    117.801047  9098.591549    717.919589
# 2    97.551991     97.551991     32.517330   117.808271    117.808271
# 3    34.913021    325.717946    162.858973    40.371399    376.641401
# 4   297.434763  23861.620343  23861.620343   301.083591  24154.346541
#
#            ind9
# 0     19.818730
# 1    717.919589
# 2     39.269424
# 3    188.320700
# 4  24154.346541

# %%
df_proc['ZIP'].dtype
# Out:
# dtype('float64')

# %%
# Converte o tipo da variável zip para string
df_proc['ZIP'] = df_proc['ZIP'].astype(int).astype(str)

# %%
df_proc['ZIP'].dtype
# Out:
# dtype('O')

# %%
# Visualiza
df_proc.head()
# Out:
#    Unnamed: 0  RECORD        BBLE  B  BLOCK  LOT EASEMENT  \
# 0         NaN       1  1000010101  1      1  101      NaN
# 1         1.0       2  1000010201  1      1  201      NaN
# 2         2.0       3  1000020001  1      2    1      NaN
# 3         3.0       4  1000020023  1      2   23      NaN
# 4         4.0       5  1000030001  1      3    1      NaN
#
#                    OWNER BLDGCL TAXCLASS  LTFRONT  LTDEPTH  EXT  STORIES  \
# 0  U S GOVT LAND & BLDGS     P7        4    500.0   1046.0  NaN      4.0
# 1  U S GOVT LAND & BLDGS     Z9        4     27.0    355.0  NaN      1.0
# 2  DEPT OF GENERAL SERVI     Y7        4    709.0    564.0    E      3.0
# 3  DEPARTMENT OF BUSINES     T2        4    793.0    551.0  NaN      2.0
# 4   PARKS AND RECREATION     Q1        4    323.0   1260.0  NaN      1.0
#
#        FULLVAL       AVLAND        AVTOT       EXLAND        EXTOT   EXCD1  \
# 0   21400000.0    4225500.0    9630000.0    4225500.0    9630000.0  4600.0
# 1  193800000.0   14310000.0   87210000.0   14310000.0   87210000.0  4600.0
# 2  104686000.0   39008700.0   47108700.0   39008700.0   47108700.0  2191.0
# 3   39200000.0   15255000.0   17640000.0   15255000.0   17640000.0  2191.0
# 4  272300000.0  121050000.0  122535000.0  121050000.0  122535000.0  2231.0
#
#              STADDR    ZIP EXMPTCL  BLDFRONT  BLDDEPTH      AVLAND2  \
# 0  1 LIBERTY ISLAND  10004      X3     382.0     318.0    3775500.0
# 1    1 ELLIS ISLAND  10004      X3     382.0     318.0   11111400.0
# 2   MARGINAL STREET  10004      X1     709.0     564.0   32321790.0
# 3            PIER 6  10004      X1      85.0     551.0   13644000.0
# 4      BATTERY PARK  10004      X1      89.0      57.0  106348680.0
#
#         AVTOT2      EXLAND2       EXTOT2  EXCD2 PERIOD     YEAR VALTYPE  \
# 0    8613000.0    3775500.0    8613000.0    NaN  FINAL  2010/11   AC-TR
# 1   80690400.0   11111400.0   80690400.0    NaN  FINAL  2010/11   AC-TR
# 2   40179510.0   32321790.0   40179510.0    NaN  FINAL  2010/11   AC-TR
# 3   15750000.0   13644000.0   15750000.0    NaN  FINAL  2010/11   AC-TR
# 4  107758350.0  106348680.0  107758350.0    NaN  FINAL  2010/11   AC-TR
#
#       AREA1     AREA2      AREA3          ind1          ind2          ind3  \
# 0  523000.0  121476.0   485904.0     40.917782    176.166486     44.041621
# 1    9585.0  121476.0   121476.0  20219.092332   1595.376865   1595.376865
# 2  399876.0  399876.0  1199628.0    261.796157    261.796157     87.265386
# 3  436943.0   46835.0    93670.0     89.714219    836.980890    418.490445
# 4  406980.0    5073.0     5073.0    669.074647  53676.325646  53676.325646
#
#           ind4          ind5          ind6         ind7          ind8  \
# 0     8.079350     34.784649      8.696162    18.413002     79.274919
# 1  1492.957746    117.801047    117.801047  9098.591549    717.919589
# 2    97.551991     97.551991     32.517330   117.808271    117.808271
# 3    34.913021    325.717946    162.858973    40.371399    376.641401
# 4   297.434763  23861.620343  23861.620343   301.083591  24154.346541
#
#            ind9
# 0     19.818730
# 1    717.919589
# 2     39.269424
# 3    188.320700
# 4  24154.346541

# %%
# Lista das variáveis para o agrupamento abaixo
list_groupby = ['ZIP', 'TAXCLASS', 'B']

# %%
# Cria variáveis que representam as médias das áreas dos imóveis por grupo com base no índice criado

# Lista
ind_lista = ['ind' + str(i) for i in range(1,10)]

# Loop
for i in list_groupby:
    for j in ind_lista:
        name_col = 'media_' + str(j) + '_grupo_' + str(i)
        df_proc[name_col] = df_proc.groupby(i)[j].transform('mean')
        name_col_final = str(j) + '_' + name_col
        df_proc[name_col_final] = df_proc[j] / df_proc[name_col]

# %%
# Visualiza
df_proc.head()
# Out:
#    Unnamed: 0  RECORD        BBLE  B  BLOCK  LOT EASEMENT  \
# 0         NaN       1  1000010101  1      1  101      NaN
# 1         1.0       2  1000010201  1      1  201      NaN
# 2         2.0       3  1000020001  1      2    1      NaN
# 3         3.0       4  1000020023  1      2   23      NaN
# 4         4.0       5  1000030001  1      3    1      NaN
#
#                    OWNER BLDGCL TAXCLASS  LTFRONT  LTDEPTH  EXT  STORIES  \
# 0  U S GOVT LAND & BLDGS     P7        4    500.0   1046.0  NaN      4.0
# 1  U S GOVT LAND & BLDGS     Z9        4     27.0    355.0  NaN      1.0
# 2  DEPT OF GENERAL SERVI     Y7        4    709.0    564.0    E      3.0
# 3  DEPARTMENT OF BUSINES     T2        4    793.0    551.0  NaN      2.0
# 4   PARKS AND RECREATION     Q1        4    323.0   1260.0  NaN      1.0
#
#        FULLVAL       AVLAND        AVTOT       EXLAND        EXTOT   EXCD1  \
# 0   21400000.0    4225500.0    9630000.0    4225500.0    9630000.0  4600.0
# 1  193800000.0   14310000.0   87210000.0   14310000.0   87210000.0  4600.0
# 2  104686000.0   39008700.0   47108700.0   39008700.0   47108700.0  2191.0
# 3   39200000.0   15255000.0   17640000.0   15255000.0   17640000.0  2191.0
# 4  272300000.0  121050000.0  122535000.0  121050000.0  122535000.0  2231.0
#
#              STADDR    ZIP EXMPTCL  BLDFRONT  BLDDEPTH      AVLAND2  \
# 0  1 LIBERTY ISLAND  10004      X3     382.0     318.0    3775500.0
# 1    1 ELLIS ISLAND  10004      X3     382.0     318.0   11111400.0
# 2   MARGINAL STREET  10004      X1     709.0     564.0   32321790.0
# 3            PIER 6  10004      X1      85.0     551.0   13644000.0
# 4      BATTERY PARK  10004      X1      89.0      57.0  106348680.0
#
#         AVTOT2      EXLAND2       EXTOT2  EXCD2 PERIOD     YEAR VALTYPE  \
# 0    8613000.0    3775500.0    8613000.0    NaN  FINAL  2010/11   AC-TR
# 1   80690400.0   11111400.0   80690400.0    NaN  FINAL  2010/11   AC-TR
# 2   40179510.0   32321790.0   40179510.0    NaN  FINAL  2010/11   AC-TR
# 3   15750000.0   13644000.0   15750000.0    NaN  FINAL  2010/11   AC-TR
# 4  107758350.0  106348680.0  107758350.0    NaN  FINAL  2010/11   AC-TR
#
#       AREA1     AREA2      AREA3          ind1          ind2          ind3  \
# 0  523000.0  121476.0   485904.0     40.917782    176.166486     44.041621
# 1    9585.0  121476.0   121476.0  20219.092332   1595.376865   1595.376865
# 2  399876.0  399876.0  1199628.0    261.796157    261.796157     87.265386
# 3  436943.0   46835.0    93670.0     89.714219    836.980890    418.490445
# 4  406980.0    5073.0     5073.0    669.074647  53676.325646  53676.325646
#
#           ind4          ind5          ind6         ind7          ind8  \
# 0     8.079350     34.784649      8.696162    18.413002     79.274919
# 1  1492.957746    117.801047    117.801047  9098.591549    717.919589
# 2    97.551991     97.551991     32.517330   117.808271    117.808271
# 3    34.913021    325.717946    162.858973    40.371399    376.641401
# 4   297.434763  23861.620343  23861.620343   301.083591  24154.346541
#
#            ind9  media_ind1_grupo_ZIP  ind1_media_ind1_grupo_ZIP  \
# 0     19.818730            308.567411                   0.132606
# 1    717.919589            308.567411                  65.525689
# 2     39.269424            308.567411                   0.848425
# 3    188.320700            308.567411                   0.290744
# 4  24154.346541            308.567411                   2.168326
#
#    media_ind2_grupo_ZIP  ind2_media_ind2_grupo_ZIP  media_ind3_grupo_ZIP  \
# 0             399.54316                   0.440920            136.599794
# 1             399.54316                   3.993003            136.599794
# 2             399.54316                   0.655239            136.599794
# 3             399.54316                   2.094845            136.599794
# 4             399.54316                 134.344249            136.599794
#
#    ind3_media_ind3_grupo_ZIP  media_ind4_grupo_ZIP  ind4_media_ind4_grupo_ZIP  \
# 0                   0.322414              43.91237                   0.183988
# 1                  11.679204              43.91237                  33.998569
# 2                   0.638840              43.91237                   2.221515
# 3                   3.063624              43.91237                   0.795061
# 4                 392.945875              43.91237                   6.773371
#
#    media_ind5_grupo_ZIP  ind5_media_ind5_grupo_ZIP  media_ind6_grupo_ZIP  \
# 0             90.426622                   0.384673             52.264394
# 1             90.426622                   1.302725             52.264394
# 2             90.426622                   1.078797             52.264394
# 3             90.426622                   3.602014             52.264394
# 4             90.426622                 263.878267             52.264394
#
#    ind6_media_ind6_grupo_ZIP  media_ind7_grupo_ZIP  ind7_media_ind7_grupo_ZIP  \
# 0                   0.166388             126.01684                   0.146115
# 1                   2.253945             126.01684                  72.201394
# 2                   0.622170             126.01684                   0.934861
# 3                   3.116060             126.01684                   0.320365
# 4                 456.555954             126.01684                   2.389233
#
#    media_ind8_grupo_ZIP  ind8_media_ind8_grupo_ZIP  media_ind9_grupo_ZIP  \
# 0            166.965375                   0.474799              58.52076
# 1            166.965375                   4.299811              58.52076
# 2            166.965375                   0.705585              58.52076
# 3            166.965375                   2.255805              58.52076
# 4            166.965375                 144.666800              58.52076
#
#    ind9_media_ind9_grupo_ZIP  media_ind1_grupo_TAXCLASS  \
# 0                   0.338662                 219.170893
# 1                  12.267776                 219.170893
# 2                   0.671034                 219.170893
# 3                   3.218015                 219.170893
# 4                 412.748342                 219.170893
#
#    ind1_media_ind1_grupo_TAXCLASS  media_ind2_grupo_TAXCLASS  \
# 0                        0.186694                 861.398717
# 1                       92.252635                 861.398717
# 2                        1.194484                 861.398717
# 3                        0.409335                 861.398717
# 4                        3.052753                 861.398717
#
#    ind2_media_ind2_grupo_TAXCLASS  media_ind3_grupo_TAXCLASS  \
# 0                        0.204512                  449.71508
# 1                        1.852077                  449.71508
# 2                        0.303920                  449.71508
# 3                        0.971653                  449.71508
# 4                       62.312985                  449.71508
#
#    ind3_media_ind3_grupo_TAXCLASS  media_ind4_grupo_TAXCLASS  \
# 0                        0.097932                  39.657134
# 1                        3.547528                  39.657134
# 2                        0.194046                  39.657134
# 3                        0.930568                  39.657134
# 4                      119.356295                  39.657134
#
#    ind4_media_ind4_grupo_TAXCLASS  media_ind5_grupo_TAXCLASS  \
# 0                        0.203730                 274.576789
# 1                       37.646638                 274.576789
# 2                        2.459885                 274.576789
# 3                        0.880372                 274.576789
# 4                        7.500158                 274.576789
#
#    ind5_media_ind5_grupo_TAXCLASS  media_ind6_grupo_TAXCLASS  \
# 0                        0.126685                 163.840149
# 1                        0.429028                 163.840149
# 2                        0.355281                 163.840149
# 3                        1.186254                 163.840149
# 4                       86.903268                 163.840149
#
#    ind6_media_ind6_grupo_TAXCLASS  media_ind7_grupo_TAXCLASS  \
# 0                        0.053077                  98.698597
# 1                        0.719000                  98.698597
# 2                        0.198470                  98.698597
# 3                        0.994011                  98.698597
# 4                      145.639640                  98.698597
#
#    ind7_media_ind7_grupo_TAXCLASS  media_ind8_grupo_TAXCLASS  \
# 0                        0.186558                 408.041766
# 1                       92.185622                 408.041766
# 2                        1.193616                 408.041766
# 3                        0.409037                 408.041766
# 4                        3.050536                 408.041766
#
#    ind8_media_ind8_grupo_TAXCLASS  media_ind9_grupo_TAXCLASS  \
# 0                        0.194281                  209.16395
# 1                        1.759427                  209.16395
# 2                        0.288716                  209.16395
# 3                        0.923046                  209.16395
# 4                       59.195770                  209.16395
#
#    ind9_media_ind9_grupo_TAXCLASS  media_ind1_grupo_B  \
# 0                        0.094752          363.950199
# 1                        3.432329          363.950199
# 2                        0.187745          363.950199
# 3                        0.900350          363.950199
# 4                      115.480448          363.950199
#
#    ind1_media_ind1_grupo_B  media_ind2_grupo_B  ind2_media_ind2_grupo_B  \
# 0                 0.112427          554.922709                 0.317461
# 1                55.554558          554.922709                 2.874953
# 2                 0.719319          554.922709                 0.471770
# 3                 0.246501          554.922709                 1.508284
# 4                 1.838369          554.922709                96.727571
#
#    media_ind3_grupo_B  ind3_media_ind3_grupo_B  media_ind4_grupo_B  \
# 0          162.784056                 0.270552            35.93064
# 1          162.784056                 9.800572            35.93064
# 2          162.784056                 0.536081            35.93064
# 3          162.784056                 2.570832            35.93064
# 4          162.784056               329.739454            35.93064
#
#    ind4_media_ind4_grupo_B  media_ind5_grupo_B  ind5_media_ind5_grupo_B  \
# 0                 0.224860           67.911275                 0.512207
# 1                41.551103           67.911275                 1.734632
# 2                 2.715008           67.911275                 1.436462
# 3                 0.971678           67.911275                 4.796228
# 4                 8.278026           67.911275               351.364636
#
#    media_ind6_grupo_B  ind6_media_ind6_grupo_B  media_ind7_grupo_B  \
# 0           31.906732                 0.272549           95.545234
# 1           31.906732                 3.692044           95.545234
# 2           31.906732                 1.019137           95.545234
# 3           31.906732                 5.104220           95.545234
# 4           31.906732               747.855349           95.545234
#
#    ind7_media_ind7_grupo_B  media_ind8_grupo_B  ind8_media_ind8_grupo_B  \
# 0                 0.192715          146.188725                 0.542278
# 1                95.228104          146.188725                 4.910909
# 2                 1.233010          146.188725                 0.805864
# 3                 0.422537          146.188725                 2.576405
# 4                 3.151215          146.188725               165.227152
#
#    media_ind9_grupo_B  ind9_media_ind9_grupo_B
# 0           45.061308                 0.439817
# 1           45.061308                15.932063
# 2           45.061308                 0.871467
# 3           45.061308                 4.179211
# 4           45.061308               536.032968

# %%
# Shape
df_proc.shape
# Out:
# (1070994, 99)

# %%
# Média para todas as variáveis
for j in ind_lista:
    name_col = 'media_' + str(j) + '_grupo_All'
    df_proc[name_col] = df_proc[j].mean()
    name_col_final = str(j) + '_' + name_col
    df_proc[name_col_final] = df_proc[j] / df_proc[name_col]

# %%
# Shape
df_proc.shape
# Out:
# (1070994, 117)

# %%
# Visualiza
df_proc.head()
# Out:
#    Unnamed: 0  RECORD        BBLE  B  BLOCK  LOT EASEMENT  \
# 0         NaN       1  1000010101  1      1  101      NaN
# 1         1.0       2  1000010201  1      1  201      NaN
# 2         2.0       3  1000020001  1      2    1      NaN
# 3         3.0       4  1000020023  1      2   23      NaN
# 4         4.0       5  1000030001  1      3    1      NaN
#
#                    OWNER BLDGCL TAXCLASS  LTFRONT  LTDEPTH  EXT  STORI
# 2             399.54316                   0.655239            136.599794
# 3             399.54316                   2.094845            136.599794
# 4             399.54316                 134.344249            136.599794
#
#    ind3_media_ind3_grupo_ZIP  media_ind4_grupo_ZIP  ind4_media_ind4_grupo_ZIP  \
# 0                   0.322414              43.91237                   0.183988
# 1                  11.679204              43.91237                  33.998569
# 2                   0.638840              43.91237                   2.221515
# 3                   3.063624              43.91237                   0.795061
# 4                 392.945875              43.91237                   6.773371
#
#    media_ind5_grupo_ZIP  ind5_media_ind5_grupo_ZIP  media_ind6_grupo_ZIP  \
# 0             90.426622                   0.384673             52.264394
# 1             90.426622                   1.302725             52.264394
# 2             90.426622                   1.078797             52.264394
# 3             90.426622                   3.602014             52.264394
# 4             90.426622                 263.878267             52.264394
#
#    ind6_media_ind6_grupo_ZIP  media_ind7_grupo_ZIP  ind7_media_ind7_grupo_ZIP  \
# 0                   0.166388             126.01684                   0.146115
# 1                   2.253945             126.01684                  72.201394
# 2                   0.622170             126.01684                   0.934861
# 3                   3.116060             126.01684                   0.320365
# 4                 456.555954             126.01684                   2.389233
#
#    media_ind8_grupo_ZIP  ind8_media_ind8_grupo_ZIP  media_ind9_grupo_ZIP  \
# 0            166.965375                   0.474799              58.52076
# 1            166.965375                   4.299811              58.52076
# 2            166.965375                   0.705585              58.52076
# 3            166.965375                   2.255805              58.52076
# 4            166.965375                 144.666800              58.52076
#
#    ind9_media_ind9_grupo_ZIP  media_ind1_grupo_TAXCLASS  \
# 0                   0.338662                 219.170893
# 1                  12.267776                 219.170893
# 2                   0.671034                 219.170893
# 3                   3.218015                 219.170893
# 4                 412.748342                 219.170893
#
#    ind1_media_ind1_grupo_TAXCLASS  media_ind2_grupo_TAXCLASS  \
# 0                        0.186694                 861.398717
# 1                       92.252635                 861.398717
# 2                        1.194484                 861.398717
# 3                        0.409335                 861.398717
# 4                        3.052753                 861.398717
#
#    ind2_media_ind2_grupo_TAXCLASS  media_ind3_grupo_TAXCLASS  \
# 0                        0.204512                  449.71508
# 1                        1.852077                  449.71508
# 2                        0.303920                  449.71508
# 3                        0.971653                  449.71508
# 4                       62.312985                  449.71508
#
#    ind3_media_ind3_grupo_TAXCLASS  media_ind4_grupo_TAXCLASS  \
# 0                        0.097932                  39.657134
# 1                        3.547528                  39.657134
# 2                        0.194046                  39.657134
# 3                        0.930568                  39.657134
# 4                      119.356295                  39.657134
#
#    ind4_media_ind4_grupo_TAXCLASS  media_ind5_grupo_TAXCLASS  \
# 0                        0.203730                 274.576789
# 1                       37.646638                 274.576789
# 2                        2.459885                 274.576789
# 3                        0.880372                 274.576789
# 4                        7.500158                 274.576789
#
#    ind5_media_ind5_grupo_TAXCLASS  media_ind6_grupo_TAXCLASS  \
# 0                        0.126685                 163.840149
# 1                        0.429028                 163.840149
# 2                        0.355281                 163.840149
# 3                        1.186254                 163.840149
# 4                       86.903268                 163.840149
#
#    ind6_media_ind6_grupo_TAXCLASS  media_ind7_grupo_TAXCLASS  \
# 0                        0.053077                  98.698597
# 1                        0.719000                  98.698597
# 2                        0.198470                  98.698597
# 3                        0.994011                  98.698597
# 4                      145.639640                  98.698597
#
#    ind7_media_ind7_grupo_TAXCLASS  media_ind8_grupo_TAXCLASS  \
# 0                        0.186558
# 4                  26.809043              44.11249                 540.926631
#
#    media_ind6_grupo_All  ind6_media_ind6_grupo_All  media_ind7_grupo_All  \
# 0             23.912472                   0.363666             30.658337
# 1             23.912472                   4.926343             30.658337
# 2             23.912472                   1.359848             30.658337
# 3             23.912472                   6.810629             30.658337
# 4             23.912472                 997.873441             30.658337
#
#    ind7_media_ind7_grupo_All  media_ind8_grupo_All  ind8_media_ind8_grupo_All  \
# 0                   0.600587             75.635641                   1.048116
# 1                 296.773816             75.635641                   9.491816
# 2                   3.842618             75.635641                   1.557576
# 3                   1.316816             75.635641                   4.979681
# 4                   9.820611             75.635641                 319.351382
#
#    media_ind9_grupo_All  ind9_media_ind9_grupo_All
# 0             34.430619                   0.575614
# 1             34.430619                  20.851196
# 2             34.430619                   1.140538
# 3             34.430619                   5.469571
# 4             34.430619                 701.536801

# %%
# Lista para as colunas criadas
cols_created = []

# %%
# Loop pelas variáveis do group by
for i in list_groupby:
    for j in ind_lista:
        cols_created.append(j + '_media_' + j + '_grupo_' + i)

# %%
len(cols_created)
# Out:
# 27

# %%
# Loop pelas colunas criadas
for j in ind_lista:
    cols_created.append(j + '_media_' + j + '_grupo_All')

# %%
len(cols_created)
# Out:
# 36

# %%
# Colunas finais para os dados
cols = list(df.columns) + cols_created

# %%
# Dataframe final
df_final = df_proc[cols]

# %%
# Shape
df_final.shape
# Out:
# (1070994, 68)

# %% [markdown]
# As variáveis ind nos ajudam a verificar quão "normal" é cada registro.

# %%
# Colunas
df_final.columns
# Out:
# Index(['RECORD', 'BBLE', 'B', 'BLOCK', 'LOT', 'EASEMENT', 'OWNER', 'BLDGCL',
#        'TAXCLASS', 'LTFRONT', 'LTDEPTH', 'EXT', 'STORIES', 'FULLVAL', 'AVLAND',
#        'AVTOT', 'EXLAND', 'EXTOT', 'EXCD1', 'STADDR', 'ZIP', 'EXMPTCL',
#        'BLDFRONT', 'BLDDEPTH', 'AVLAND2', 'AVTOT2', 'EXLAND2', 'EXTOT2',
#        'EXCD2', 'PERIOD', 'YEAR', 'VALTYPE', 'ind1_media_ind1_grupo_ZIP',
#        'ind2_media_ind2_grupo_ZIP', 'ind3_media_ind3_grupo_ZIP',
#        'ind4_media_ind4_grupo_ZIP', 'ind5_media_ind5_grupo_ZIP',
#        'ind6_media_ind6_grupo_ZIP', 'ind7_media_ind7_grupo_ZIP',
#        'ind8_media_ind8_grupo_ZIP', 'ind9_media_ind9_grupo_ZIP',
#        'ind1_media_ind1_grupo_TAXCLASS', 'ind2_media_ind2_grupo_TAXCLASS',
#        'ind3_media_ind3_grupo_TAXCLASS', 'ind4_media_ind4_grupo_TAXCLASS',
#        'ind5_media_ind5_grupo_TAXCLASS', 'ind6_media_ind6_grupo_TAXCLASS',
#        'ind7_media_ind7_grupo_TAXCLASS', 'ind8_media_ind8_grupo_TAXCLASS',
#        'ind9_media_ind9_grupo_TAXCLASS', 'ind1_media_ind1_grupo_B',
#        'ind2_media_ind2_grupo_B', 'ind3_media_ind3_grupo_B',
#        'ind4_media_ind4_grupo_B', 'ind5_media_ind5_grupo_B',
#        'ind6_media_ind6_grupo_B', 'ind7_media_ind7_grupo_B',
#        'ind8_media_ind8_grupo_B', 'ind9_media_ind9_grupo_B',
#        'ind1_media_ind1_grupo_All', 'ind2_media_ind2_grupo_All',
#        'ind3_media_ind3_grupo_All', 'ind4_media_ind4_grupo_All',
#        'ind5_media_ind5_grupo_All', 'ind6_media_ind6_grupo_All',
#        'ind7_media_ind7_grupo_All', 'ind8_media_ind8_grupo_All',
#        'ind9_media_ind9_grupo_All'],
#       dtype='object')

# %%
# Visualiza
df_final.head()
# Out:
#    RECORD        BBLE  B  BLOCK  LOT EASEMENT                  OWNER BLDGCL  \
# 0       1  1000010101  1      1  101      NaN  U S GOVT LAND & BLDGS     P7
# 1       2  1000010201  1      1  201      NaN  U S GOVT LAND & BLDGS     Z9
# 2       3  1000020001  1      2    1      NaN  DEPT OF GENERAL SERVI     Y7
# 3       4  1000020023  1      2   23      NaN  DEPARTMENT OF BUSINES     T2
# 4       5  1000030001  1      3    1      NaN   PARKS AND RECREATION     Q1
#
#   TAXCLASS  LTFRONT  LTDEPTH  EXT  STORIES      FULLVAL       AVLAND  \
# 0        4    500.0   1046.0  NaN      4.0   21400000.0    4225500.0
# 1        4     27.0    355.0  NaN      1.0  193800000.0   14310000.0
# 2        4    709.0    564.0    E      3.0  104686000.0   39008700.0
# 3        4    793.0    551.0  NaN      2.0   39200000.0   15255000.0
# 4        4    323.0   1260.0  NaN      1.0  272300000.0  121050000.0
#
#          AVTOT       EXLAND        EXTOT   EXCD1            STADDR    ZIP  \
# 0    9630000.0    4225500.0    9630000.0  4600.0  1 LIBERTY ISLAND  10004
# 1   87210000.0   14310000.0   87210000.0  4600.0    1 ELLIS ISLAND  10004
# 2   47108700.0   39008700.0   47108700.0  2191.0   MARGINAL STREET  10004
# 3   17640000.0   15255000.0   17640000.0  2191.0            PIER 6  10004
# 4  122535000.0  121050000.0  122535000.0  2231.0      BATTERY PARK  10004
#
#   EXMPTCL  BLDFRONT  BLDDEPTH      AVLAND2       AVTOT2      EXLAND2  \
# 0      X3     382.0     318.0    3775500.0    8613000.0    3775500.0
# 1      X3     382.0     318.0   11111400.0   80690400.0   11111400.0
# 2      X1     709.0     564.0   32321790.0   40179510.0   32321790.0
# 3      X1      85.0     551.0   13644000.0   15750000.0   13644000.0
# 4      X1      89.0      57.0  106348680.0  107758350.0  106348680.0
#
#         EXTOT2  EXCD2 PERIOD     YEAR VALTYPE  ind1_media_ind1_grupo_ZIP  \
# 0    8613000.0    NaN  FINAL  2010/11   AC-TR                   0.132606
# 1   80690400.0    NaN  FINAL  2010/11   AC-TR                  65.525689
# 2   40179510.0    NaN  FINAL  2010/11   AC-TR                   0.848425
# 3   15750000.0    NaN  FINAL  2010/11   AC-TR                   0.290744
# 4  107758350.0    NaN  FINAL  2010/11   AC-TR                   2.168326
#
#    ind2_media_ind2_grupo_ZIP  ind3_media_ind3_grupo_ZIP  \
# 0                   0.440920                   0.322414
# 1                   3.993003                  11.679204
# 2                   0.655239                   0.638840
# 3                   2.094845                   3.063624
# 4                 134.344249                 392.945875
#
#    ind4_media_ind4_grupo_ZIP  ind5_media_ind5_grupo_ZIP  \
# 0                   0.183988                   0.384673
# 1                  33.998569                   1.302725
# 2                   2.221515                   1.078797
# 3                   0.795061                   3.602014
# 4                   6.773371                 263.878267
#
#    ind6_media_ind6_grupo_ZIP  ind7_media_ind7_grupo_ZIP  \
# 0                   0.166388                   0.146115
# 1                   2.253945                  72.201394
# 2                   0.622170                   0.934861
# 3                   3.116060                   0.320365
# 4                 456.555954                   2.389233
#
#    ind8_media_ind8_grupo_ZIP  ind9_media_ind9_grupo_ZIP  \
# 0                   0.474799                   0.338662
# 1                   4.299811                  12.267776
# 2                   0.705585                   0.671034
# 3                   2.255805                   3.218015
# 4                 144.666800                 412.748342
#
#    ind1_media_ind1_grupo_TAXCLASS  ind2_media_ind2_grupo_TAXCLASS  \
# 0                        0.186694                        0.204512
# 1                       92.252635                        1.852077
# 2                        1.194484                        0.303920
# 3                        0.409335                        0.971653
# 4                        3.052753                       62.312985
#
#    ind3_media_ind3_grupo_TAXCLASS  ind4_media_ind4_grupo_TAXCLASS  \
# 0                        0.097932                        0.203730
# 1                        3.547528                       37.646638
# 2                        0.194046                        2.459885
# 3                        0.930568                        0.880372
# 4                      119.356295                        7.500158
#
#    ind5_media_ind5_grupo_TAXCLASS  ind6_media_ind6_grupo_TAXCLASS  \
# 0                        0.126685                        0.053077
# 1                        0.429028                        0.719000
# 2                        0.355281                        0.198470
# 3                        1.186254                        0.994011
# 4                       86.903268                      145.639640
#
#    ind7_media_ind7_grupo_TAXCLASS  ind8_media_ind8_grupo_TAXCLASS  \
# 0                        0.186558                        0.194281
# 1                       92.185622                        1.759427
# 2                        1.193616                        0.288716
# 3                        0.409037                        0.923046
# 4                        3.050536                       59.195770
#
#    ind9_media_ind9_grupo_TAXCLASS  ind1_media_ind1_grupo_B  \
# 0                        0.094752                 0.112427
# 1                        3.432329                55.554558
# 2                        0.187745                 0.719319
# 3                        0.900350                 0.246501
# 4                      115.480448                 1.838369
#
#    ind2_media_ind2_grupo_B  ind3_media_ind3_grupo_B  ind4_media_ind4_grupo_B  \
# 0                 0.317461                 0.270552                 0.224860
# 1                 2.874953                 9.800572                41.551103
# 2                 0.471770                 0.536081                 2.715008
# 3                 1.508284                 2.570832                 0.971678
# 4                96.727571               329.739454                 8.278026
#
#    ind5_media_ind5_grupo_B  ind6_media_ind6_grupo_B  ind7_media_ind7_grupo_B  \
# 0                 0.512207                 0.272549                 0.192715
# 1                 1.734632                 3.692044                95.228104
# 2                 1.436462                 1.019137                 1.233010
# 3                 4.796228                 5.104220                 0.422537
# 4               351.364636               747.855349                 3.151215
#
#    ind8_media_ind8_grupo_B  ind9_media_ind9_grupo_B  \
# 0                 0.542278                 0.439817
# 1                 4.910909                15.932063
# 2                 0.805864                 0.871467
# 3                 2.576405                 4.179211
# 4               165.227152               536.032968
#
#    ind1_media_ind1_grupo_All  ind2_media_ind2_grupo_All  \
# 0                   0.119039                   0.290093
# 1                  58.821734                   2.627102
# 2                   0.761622                   0.431099
# 3                   0.260998                   1.378254
# 4                   1.946484                  88.388624
#
#    ind3_media_ind3_grupo_All  ind4_media_ind4_grupo_All  \
# 0                   0.155256                   0.728226
# 1                   5.624045                 134.566543
# 2                   0.307629                   8.792770
# 3                   1.475269                   3.146857
# 4                 189.220556                  26.809043
#
#    ind5_media_ind5_grupo_All  ind6_media_ind6_grupo_All  \
# 0                   0.788544                   0.363666
# 1                   2.670469                   4.926343
# 2                   2.211437                   1.359848
# 3                   7.383803                   6.810629
# 4                 540.926631                 997.873441
#
#    ind7_media_ind7_grupo_All  ind8_media_ind8_grupo_All  \
# 0                   0.600587                   1.048116
# 1                 296.773816                   9.491816
# 2                   3.842618                   1.557576
# 3                   1.316816                   4.979681
# 4                   9.820611                 319.351382
#
#    ind9_media_ind9_grupo_All
# 0                   0.575614
# 1                  20.851196
# 2                   1.140538
# 3                   5.469571
# 4                 701.536801

# %%
# Salva em disco
df_final.to_csv('dados/dataset_final.csv')

# %%
# Carrega do disco
df_final = pd.read_csv('dados/dataset_final.csv')

# %%
# Dataframe final para a modelagem
df = df_final.copy()

# %% [markdown]
# ## Calculando o Score de Fraude 1 com PCA
#
# Vamos criar o score de fraude usando PCA em escala Z. Essa é uma abordagem de aprendizado não supervisionado.

# %%
# Imports
import sklearn
from sklearn import preprocessing
from sklearn.decomposition import PCA

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Data Science Academy" --iversions
# Out:
# Author: Data Science Academy
#
# numpy     : 1.20.3
# pandas    : 1.3.2
# seaborn   : 0.11.2
# matplotlib: 3.4.2
# sklearn   : 0.24.2

# %% [markdown]
# ### Padronização das Variáveis

# %%
# Shape
df.shape
# Out:
# (1070994, 69)

# %%
# Colunas
df.columns
# Out:
# Index(['Unnamed: 0', 'RECORD', 'BBLE', 'B', 'BLOCK', 'LOT', 'EASEMENT',
#        'OWNER', 'BLDGCL', 'TAXCLASS', 'LTFRONT', 'LTDEPTH', 'EXT', 'STORIES',
#        'FULLVAL', 'AVLAND', 'AVTOT', 'EXLAND', 'EXTOT', 'EXCD1', 'STADDR',
#        'ZIP', 'EXMPTCL', 'BLDFRONT', 'BLDDEPTH', 'AVLAND2', 'AVTOT2',
#        'EXLAND2', 'EXTOT2', 'EXCD2', 'PERIOD', 'YEAR', 'VALTYPE',
#        'ind1_media_ind1_grupo_ZIP', 'ind2_media_ind2_grupo_ZIP',
#        'ind3_media_ind3_grupo_ZIP', 'ind4_media_ind4_grupo_ZIP',
#        'ind5_media_ind5_grupo_ZIP', 'ind6_media_ind6_grupo_ZIP',
#        'ind7_media_ind7_grupo_ZIP', 'ind8_media_ind8_grupo_ZIP',
#        'ind9_media_ind9_grupo_ZIP', 'ind1_media_ind1_grupo_TAXCLASS',
#        'ind2_media_ind2_grupo_TAXCLASS', 'ind3_media_ind3_grupo_TAXCLASS',
#        'ind4_media_ind4_grupo_TAXCLASS', 'ind5_media_ind5_grupo_TAXCLASS',
#        'ind6_media_ind6_grupo_TAXCLASS', 'ind7_media_ind7_grupo_TAXCLASS',
#        'ind8_media_ind8_grupo_TAXCLASS', 'ind9_media_ind9_grupo_TAXCLASS',
#        'ind1_media_ind1_grupo_B', 'ind2_media_ind2_grupo_B',
#        'ind3_media_ind3_grupo_B', 'ind4_media_ind4_grupo_B',
#        'ind5_media_ind5_grupo_B', 'ind6_media_ind6_grupo_B',
#        'ind7_media_ind7_grupo_B', 'ind8_media_ind8_grupo_B',
#        'ind9_media_ind9_grupo_B', 'ind1_media_ind1_grupo_All',
#        'ind2_media_ind2_grupo_All', 'ind3_media_ind3_grupo_All',
#        'ind4_media_ind4_grupo_All', 'ind5_media_ind5_grupo_All',
#        'ind6_media_ind6_grupo_All', 'ind7_media_ind7_grupo_All',
#        'ind8_media_ind8_grupo_All', 'ind9_media_ind9_grupo_All'],
#       dtype='object')

# %%
# Tipos de dados
df.dtypes
# Out:
# Unnamed: 0                          int64
# RECORD                              int64
# BBLE                               object
# B                                   int64
# BLOCK                               int64
# LOT                                 int64
# EASEMENT                           object
# OWNER                              object
# BLDGCL                             object
# TAXCLASS                           object
# LTFRONT                           float64
# LTDEPTH                           float64
# EXT                                object
# STORIES                           float64
# FULLVAL                           float64
# AVLAND                            float64
# AVTOT                             float64
# EXLAND                            float64
# EXTOT                             float64
# EXCD1                             float64
# STADDR                             object
# ZIP                                 int64
# EXMPTCL                            object
# BLDFRONT                          float64
# BLDDEPTH                          float64
# AVLAND2                           float64
# AVTOT2                            float64
# EXLAND2                           float64
# EXTOT2                            float64
# EXCD2                             float64
# PERIOD                             object
# YEAR                               object
# VALTYPE                            object
# ind1_media_ind1_grupo_ZIP         float64
# ind2_media_ind2_grupo_ZIP         float64
# ind3_media_ind3_grupo_ZIP         float64
# ind4_media_ind4_grupo_ZIP         float64
# ind5_media_ind5_grupo_ZIP         float64
# ind6_media_ind6_grupo_ZIP         float64
# ind7_media_ind7_grupo_ZIP         float64
# ind8_media_ind8_grupo_ZIP         float64
# ind9_media_ind9_grupo_ZIP         float64
# ind1_media_ind1_grupo_TAXCLASS    float64
# ind2_media_ind2_grupo_TAXCLASS    float64
# ind3_media_ind3_grupo_TAXCLASS    float64
# ind4_media_ind4_grupo_TAXCLASS    float64
# ind5_media_ind5_grupo_TAXCLASS    float64
# ind6_media_ind6_grupo_TAXCLASS    float64
# ind7_media_ind7_grupo_TAXCLASS    float64
# ind8_media_ind8_grupo_TAXCLASS    float64
# ind9_media_ind9_grupo_TAXCLASS    float64
# ind1_media_ind1_grupo_B           float64
# ind2_media_ind2_grupo_B           float64
# ind3_media_ind3_grupo_B           float64
# ind4_media_ind4_grupo_B           float64
# ind5_media_ind5_grupo_B           float64
# ind6_media_ind6_grupo_B           float64
# ind7_media_ind7_grupo_B           float64
# ind8_media_ind8_grupo_B           float64
# ind9_media_ind9_grupo_B           float64
# ind1_media_ind1_grupo_All         float64
# ind2_media_ind2_grupo_All         float64
# ind3_media_ind3_grupo_All         float64
# ind4_media_ind4_grupo_All         float64
# ind5_media_ind5_grupo_All         float64
# ind6_media_ind6_grupo_All         float64
# ind7_media_ind7_grupo_All         float64
# ind8_media_ind8_grupo_All         float64
# ind9_media_ind9_grupo_All         float64
# dtype: object

# %%
# Busca as 36 últimas colunas (com as variáveis que nós criamos na Engenharia de Atributos)
df.iloc[:,-36:].columns
# Out:
# Index(['ind1_media_ind1_grupo_ZIP', 'ind2_media_ind2_grupo_ZIP',
#        'ind3_media_ind3_grupo_ZIP', 'ind4_media_ind4_grupo_ZIP',
#        'ind5_media_ind5_grupo_ZIP', 'ind6_media_ind6_grupo_ZIP',
#        'ind7_media_ind7_grupo_ZIP', 'ind8_media_ind8_grupo_ZIP',
#        'ind9_media_ind9_grupo_ZIP', 'ind1_media_ind1_grupo_TAXCLASS',
#        'ind2_media_ind2_grupo_TAXCLASS', 'ind3_media_ind3_grupo_TAXCLASS',
#        'ind4_media_ind4_grupo_TAXCLASS', 'ind5_media_ind5_grupo_TAXCLASS',
#        'ind6_media_ind6_grupo_TAXCLASS', 'ind7_media_ind7_grupo_TAXCLASS',
#        'ind8_media_ind8_grupo_TAXCLASS', 'ind9_media_ind9_grupo_TAXCLASS',
#        'ind1_media_ind1_grupo_B', 'ind2_media_ind2_grupo_B',
#        'ind3_media_ind3_grupo_B', 'ind4_media_ind4_grupo_B',
#        'ind5_media_ind5_grupo_B', 'ind6_media_ind6_grupo_B',
#        'ind7_media_ind7_grupo_B', 'ind8_media_ind8_grupo_B',
#        'ind9_media_ind9_grupo_B', 'ind1_media_ind1_grupo_All',
#        'ind2_media_ind2_grupo_All', 'ind3_media_ind3_grupo_All',
#        'ind4_media_ind4_grupo_All', 'ind5_media_ind5_grupo_All',
#        'ind6_media_ind6_grupo_All', 'ind7_media_ind7_grupo_All',
#        'ind8_media_ind8_grupo_All', 'ind9_media_ind9_grupo_All'],
#       dtype='object')

# %%
# Cria o objeto scaler
scaler = preprocessing.StandardScaler()

# %%
# Aplica o scaler às variáveis
arr_scaled = scaler.fit_transform(df.iloc[:,-36:])

# %%
# Cria o dataframe
df_scaled = pd.DataFrame(arr_scaled, columns = cols_created)

# %%
# Visualiza a amostra
df_scaled.head()
# Out:
#    ind1_media_ind1_grupo_ZIP  ind2_media_ind2_grupo_ZIP  \
# 0                  -0.217642                  -0.058083
# 1                  16.190473                   0.310943
# 2                  -0.038033                  -0.035817
# 3                  -0.177963                   0.113743
# 4                   0.293151                  13.853133
#
#    ind3_media_ind3_grupo_ZIP  ind4_media_ind4_grupo_ZIP  \
# 0                  -0.061874                  -0.063673
# 1                   0.975171                   2.574879
# 2                  -0.032979                   0.095315
# 3                   0.188440                  -0.015991
# 4                  35.790522                   0.450496
#
#    ind5_media_ind5_grupo_ZIP  ind6_media_ind6_grupo_ZIP  \
# 0                  -0.024200                  -0.031534
# 1                   0.011906                   0.047434
# 2                   0.003099                  -0.014292
# 3                   0.102335                   0.080045
# 4                  10.338813                  17.232588
#
#    ind7_media_ind7_grupo_ZIP  ind8_media_ind8_grupo_ZIP  \
# 0                  -0.087295                  -0.024959
# 1                   7.279154                   0.156815
# 2                  -0.006659                  -0.013991
# 3                  -0.069481                   0.059679
# 4                   0.142026                   6.827386
#
#    ind9_media_ind9_grupo_ZIP  ind1_media_ind1_grupo_TAXCLASS  \
# 0                  -0.029884                       -0.141901
# 1                   0.509155                       15.921190
# 2                  -0.014865                        0.033932
# 3                   0.100225                       -0.103056
# 4                  18.605602                        0.358152
#
#    ind2_media_ind2_grupo_TAXCLASS  ind3_media_ind3_grupo_TAXCLASS  \
# 0                       -0.032287                       -0.010859
# 1                        0.034584                        0.030668
# 2                       -0.028252                       -0.009702
# 3                       -0.001151                       -0.000836
# 4                        2.488535                        1.424803
#
#    ind4_media_ind4_grupo_TAXCLASS  ind5_media_ind5_grupo_TAXCLASS  \
# 0                       -0.098582                       -0.014261
# 1                        4.537038                       -0.009324
# 2                        0.180741                       -0.010528
# 3                       -0.014811                        0.003042
# 4                        0.804752                        1.402810
#
#    ind6_media_ind6_grupo_TAXCLASS  ind7_media_ind7_grupo_TAXCLASS  \
# 0                       -0.006837                       -0.118500
# 1                       -0.002029                       13.283676
# 2                       -0.005787                        0.028206
# 3                       -0.000043                       -0.086090
# 4                        1.044369                        0.298717
#
#    ind8_media_ind8_grupo_TAXCLASS  ind9_media_ind9_grupo_TAXCLASS  \
# 0                       -0.031582                       -0.010875
# 1                        0.029767                        0.029220
# 2                       -0.027880                       -0.009758
# 3                       -0.003016                       -0.001197
# 4                        2.281088                        1.375258
#
#    ind1_media_ind1_grupo_B  ind2_media_ind2_grupo_B  ind3_media_ind3_grupo_B  \
# 0                -0.060567                -0.046552                -0.041157
# 1                 3.722748                 0.127880                 0.496549
# 2                -0.019153                -0.036028                -0.026175
# 3                -0.051418                 0.034667                 0.088630
# 4                 0.057209                 6.529051                18.548245
#
#    ind4_media_ind4_grupo_B  ind5_media_ind5_grupo_B  ind6_media_ind6_grupo_B  \
# 0                -0.033691                -0.006001                -0.009110
# 1                 1.762530                 0.009037                 0.033714
# 2                 0.074542                 0.005369                 0.000240
# 3                -0.001231                 0.046701                 0.051399
# 4                 0.316335                 4.310177                 9.353199
#
#    ind7_media_ind7_grupo_B  ind8_media_ind8_grupo_B  ind9_media_ind9_grupo_B  \
# 0                -0.054825                -0.007588                -0.009502
# 1                 6.399266                 0.064835                 0.253274
# 2                 0.015824                -0.003218                -0.002180
# 3                -0.039217                 0.026134                 0.053925
# 4                 0.146094                 2.722560                 9.075113
#
#    ind1_media_ind1_grupo_All  ind2_media_ind2_grupo_All  \
# 0                  -0.040192                  -0.045643
# 1                   2.637975                   0.104614
# 2                  -0.010875                  -0.036577
# 3                  -0.033715                   0.024320
# 4                   0.043181                   5.618616
#
#    ind3_media_ind3_grupo_All  ind4_media_ind4_grupo_All  \
# 0                  -0.049198                  -0.012697
# 1                   0.269305                   6.240320
# 2                  -0.040324                   0.364084
# 3                   0.027680                   0.100303
# 4                  10.961996                   1.205816
#
#    ind5_media_ind5_grupo_All  ind6_media_ind6_grupo_All  \
# 0                  -0.002692                  -0.007698
# 1                   0.021270                   0.047501
# 2                   0.015425                   0.004353
# 3                   0.081283                   0.070297
# 4                   6.874744                  12.060259
#
#    ind7_media_ind7_grupo_All  ind8_media_ind8_grupo_All  \
# 0                  -0.030665                   0.000833
# 1                  22.708403                   0.147039
# 2                   0.218246                   0.009655
# 3                   0.024324                   0.068910
# 4                   0.677213                   5.512374
#
#    ind9_media_ind9_grupo_All
# 0                  -0.006849
# 1                   0.320354
# 2                   0.002268
# 3                   0.072129
# 4                  11.305086

# %% [markdown]
# ### Aplicando PCA

# %%
# Cria e treina o modelo PCA
# Queremos encontrar o valor ideal de componentes principais
pca = PCA().fit(df_scaled)

# %%
# Visualiza a Soma Cumulativa da Variância Explicada
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Número de Componentes')
plt.ylabel('Percentual de Variância Explicada') 
plt.title('Variância Explicada')
plt.show()

# %%
# Pelo gráfico acima 10 componentes principais são suficentes. Usaremos esse valor.
pca = PCA(n_components = 10)

# %%
# Fit e transform do modelo pca
arr_pca = pca.fit_transform(df_scaled)

# %%
# Cria a lista colunas doo PCA
cols_PCA = ['PCA' + str(i) for i in range(1,11)]
cols_PCA
# Out:
# ['PCA1',
#  'PCA2',
#  'PCA3',
#  'PCA4',
#  'PCA5',
#  'PCA6',
#  'PCA7',
#  'PCA8',
#  'PCA9',
#  'PCA10']

# %%
# Armazena os componentes em um dataframe
df_scaled_pca = pd.DataFrame(arr_pca, columns = cols_PCA)

# %%
# Visualiza amostra
df_scaled_pca.head()
# Out:
#         PCA1       PCA2       PCA3      PCA4       PCA5      PCA6       PCA7  \
# 0  -0.189786  -0.225928  -0.070251 -0.061773   0.068859 -0.138118   0.036129
# 1   9.243828  28.165459   9.693018  2.014850  -3.490405  6.142835   0.500528
# 2   0.037149   0.276740   0.007367  0.076539   0.023640 -0.144762  -0.026214
# 3   0.224525  -0.182780  -0.168560 -0.105874  -0.069198 -0.069884  -0.085056
# 4  43.391792  -9.788772 -11.472998 -9.508949 -21.790186  4.601164 -14.752986
#
#         PCA8      PCA9     PCA10
# 0  -0.006097  0.054610 -0.030597
# 1   0.333165  9.767034  1.717747
# 2   0.050815  0.322028 -0.075613
# 3  -0.009260  0.131555 -0.037318
# 4 -10.398444  1.856950  4.854386

# %% [markdown]
# ### Aplicação da Escala Z em Componentes PCA Padronizados

# %%
# Fit e transform nos dados
arr_pca_scaled_z = scaler.fit_transform(df_scaled_pca)

# %%
# Cria o dataframe
df_pca_scaled_z = pd.DataFrame(arr_pca_scaled_z, columns = cols_PCA)

# %%
# Visualiza
df_pca_scaled_z.head()
# Out:
#         PCA1       PCA2      PCA3      PCA4       PCA5      PCA6       PCA7  \
# 0  -0.044612  -0.084651 -0.040333 -0.044975   0.056453 -0.120501   0.037794
# 1   2.172910  10.553095  5.564976  1.466945  -2.861554  5.359333   0.523599
# 2   0.008733   0.103690  0.004230  0.055726   0.019381 -0.126298  -0.027422
# 3   0.052778  -0.068484 -0.096774 -0.077083  -0.056731 -0.060970  -0.088976
# 4  10.199938  -3.667678 -6.586902 -6.923150 -17.864340  4.014297 -15.432997
#
#         PCA8       PCA9     PCA10
# 0  -0.007035   0.093356 -0.062923
# 1   0.384417  16.696597  3.532624
# 2   0.058632   0.550502 -0.155501
# 3  -0.010684   0.224892 -0.076747
# 4 -11.998072   3.174429  9.983262

# %% [markdown]
# ### Calculando o Fraud Score

# %%
# Loop para calcular o score por componente PCA
for i in range(1,11):
    col_name = 'score' + str(i)
    pca_col_name = 'PCA' + str(i)
    df_pca_scaled_z[col_name] = df_pca_scaled_z[pca_col_name] ** 2

# %%
# Visualiza
df_pca_scaled_z.head()
# Out:
#         PCA1       PCA2      PCA3      PCA4       PCA5      PCA6       PCA7  \
# 0  -0.044612  -0.084651 -0.040333 -0.044975   0.056453 -0.120501   0.037794
# 1   2.172910  10.553095  5.564976  1.466945  -2.861554  5.359333   0.523599
# 2   0.008733   0.103690  0.004230  0.055726   0.019381 -0.126298  -0.027422
# 3   0.052778  -0.068484 -0.096774 -0.077083  -0.056731 -0.060970  -0.088976
# 4  10.199938  -3.667678 -6.586902 -6.923150 -17.864340  4.014297 -15.432997
#
#         PCA8       PCA9     PCA10      score1      score2     score3  \
# 0  -0.007035   0.093356 -0.062923    0.001990    0.007166   0.001627
# 1   0.384417  16.696597  3.532624    4.721539  111.367812  30.968961
# 2   0.058632   0.550502 -0.155501    0.000076    0.010752   0.000018
# 3  -0.010684   0.224892 -0.076747    0.002786    0.004690   0.009365
# 4 -11.998072   3.174429  9.983262  104.038733   13.451864  43.387278
#
#       score4      score5     score6      score7      score8      score9  \
# 0   0.002023    0.003187   0.014521    0.001428    0.000049    0.008715
# 1   2.151928    8.188489  28.722446    0.274156    0.147776  278.776335
# 2   0.003105    0.000376   0.015951    0.000752    0.003438    0.303052
# 3   0.005942    0.003218   0.003717    0.007917    0.000114    0.050576
# 4  47.930008  319.134642  16.114584  238.177408  143.953741   10.076996
#
#      score10
# 0   0.003959
# 1  12.479435
# 2   0.024181
# 3   0.005890
# 4  99.665519

# %%
# Colunas
col_scores = ['score' + str(i) for i in range(1,11)]

# %%
# Calcula o score de fraude
df_pca_scaled_z['Fraud Score 1'] = df_pca_scaled_z[col_scores].sum(axis = 1) ** (1 / 2)

# %%
# Visualiza
df_pca_scaled_z.head()
# Out:
#         PCA1       PCA2      PCA3      PCA4       PCA5      PCA6       PCA7  \
# 0  -0.044612  -0.084651 -0.040333 -0.044975   0.056453 -0.120501   0.037794
# 1   2.172910  10.553095  5.564976  1.466945  -2.861554  5.359333   0.523599
# 2   0.008733   0.103690  0.004230  0.055726   0.019381 -0.126298  -0.027422
# 3   0.052778  -0.068484 -0.096774 -0.077083  -0.056731 -0.060970  -0.088976
# 4  10.199938  -3.667678 -6.586902 -6.923150 -17.864340  4.014297 -15.432997
#
#         PCA8       PCA9     PCA10      score1      score2     score3  \
# 0  -0.007035   0.093356 -0.062923    0.001990    0.007166   0.001627
# 1   0.384417  16.696597  3.532624    4.721539  111.367812  30.968961
# 2   0.058632   0.550502 -0.155501    0.000076    0.010752   0.000018
# 3  -0.010684   0.224892 -0.076747    0.002786    0.004690   0.009365
# 4 -11.998072   3.174429  9.983262  104.038733   13.451864  43.387278
#
#       score4      score5     score6      score7      score8      score9  \
# 0   0.002023    0.003187   0.014521    0.001428    0.000049    0.008715
# 1   2.151928    8.188489  28.722446    0.274156    0.147776  278.776335
# 2   0.003105    0.000376   0.015951    0.000752    0.003438    0.303052
# 3   0.005942    0.003218   0.003717    0.007917    0.000114    0.050576
# 4  47.930008  319.134642  16.114584  238.177408  143.953741   10.076996
#
#      score10  Fraud Score 1
# 0   0.003959       0.211342
# 1  12.479435      21.858611
# 2   0.024181       0.601415
# 3   0.005890       0.306946
# 4  99.665519      32.185878

# %%
# Dataframe final com o score
df_score1 = pd.merge(df, df_pca_scaled_z.iloc[:,-1], left_index = True, right_index = True)

# %%
# Shape
df_score1.shape
# Out:
# (1070994, 70)

# %%
# Visualiza
df_score1.head()
# Out:
#    Unnamed: 0  RECORD        BBLE  B  BLOCK  LOT EASEMENT  \
# 0           0       1  1000010101  1      1  101      NaN
# 1           1       2  1000010201  1      1  201      NaN
# 2           2       3  1000020001  1      2    1      NaN
# 3           3       4  1000020023  1      2   23      NaN
# 4           4       5  1000030001  1      3    1      NaN
#
#                    OWNER BLDGCL TAXCLASS  LTFRONT  LTDEPTH  EXT  STORIES  \
# 0  U S GOVT LAND & BLDGS     P7        4    500.0   1046.0  NaN      4.0
# 1  U S GOVT LAND & BLDGS     Z9        4     27.0    355.0  NaN      1.0
# 2  DEPT OF GENERAL SERVI     Y7        4    709.0    564.0    E      3.0
# 3  DEPARTMENT OF BUSINES     T2        4    793.0    551.0  NaN      2.0
# 4   PARKS AND RECREATION     Q1        4    323.0   1260.0  NaN      1.0
#
#        FULLVAL       AVLAND        AVTOT       EXLAND        EXTOT   EXCD1  \
# 0   21400000.0    4225500.0    9630000.0    4225500.0    9630000.0  4600.0
# 1  193800000.0   14310000.0   87210000.0   14310000.0   87210000.0  4600.0
# 2  104686000.0   39008700.0   47108700.0   39008700.0   47108700.0  2191.0
# 3   39200000.0   15255000.0   17640000.0   15255000.0   17640000.0  2191.0
# 4  272300000.0  121050000.0  122535000.0  121050000.0  122535000.0  2231.0
#
#              STADDR    ZIP EXMPTCL  BLDFRONT  BLDDEPTH      AVLAND2  \
# 0  1 LIBERTY ISLAND  10004      X3     382.0     318.0    3775500.0
# 1    1 ELLIS ISLAND  10004      X3     382.0     318.0   11111400.0
# 2   MARGINAL STREET  10004      X1     709.0     564.0   32321790.0
# 3            PIER 6  10004      X1      85.0     551.0   13644000.0
# 4      BATTERY PARK  10004      X1      89.0      57.0  106348680.0
#
#         AVTOT2      EXLAND2       EXTOT2  EXCD2 PERIOD     YEAR VALTYPE  \
# 0    8613000.0    3775500.0    8613000.0    NaN  FINAL  2010/11   AC-TR
# 1   80690400.0   11111400.0   80690400.0    NaN  FINAL  2010/11   AC-TR
# 2   40179510.0   32321790.0   40179510.0    NaN  FINAL  2010/11   AC-TR
# 3   15750000.0   13644000.0   15750000.0    NaN  FINAL  2010/11   AC-TR
# 4  107758350.
#
#    ind5_media_ind5_grupo_All  ind6_media_ind6_grupo_All  \
# 0                   0.788544                   0.363666
# 1                   2.670469                   4.926343
# 2                   2.211437                   1.359848
# 3                   7.383803                   6.810629
# 4                 540.926631                 997.873441
#
#    ind7_media_ind7_grupo_All  ind8_media_ind8_grupo_All  \
# 0                   0.600587                   1.048116
# 1                 296.773816                   9.491816
# 2                   3.842618                   1.557576
# 3                   1.316816                   4.979681
# 4                   9.820611                 319.351382
#
#    ind9_media_ind9_grupo_All  Fraud Score 1
# 0                   0.575614       0.211342
# 1                  20.851196      21.858611
# 2                   1.140538       0.601415
# 3                   5.469571       0.306946
# 4                 701.536801      32.185878

# %% [markdown]
# ## Calculando o Score de Fraude 2 com Deep Learning
#
# Usaremos um modelo Autoencoder. Essa é uma abordagem de aprendizado não supervisionado.

# %% [markdown]
# https://www.deeplearningbook.com.br/

# %%
# Imports
import tensorflow as tf
import tensorflow.keras as keras
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from tensorflow.keras import regularizers

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Data Science Academy" --iversions
# Out:
# Author: Data Science Academy
#
# numpy     : 1.20.3
# pandas    : 1.3.2
# seaborn   : 0.11.2
# matplotlib: 3.4.2
# sklearn   : 0.24.2
# tensorflow: 2.5.0

# %%
# Carrega os dados com os 10 componentes principais
df_pca = df_pca_scaled_z.iloc[:,:10]

# %%
# Divisão em treino e teste
X_treino, X_teste = train_test_split(df_pca, test_size = 0.2, random_state = 42)

# %%
# Extrai os valores
X_treino = X_treino.values
X_teste = X_teste.values

# %%
# Shape
X_treino.shape
# Out:
# (856795, 10)

# %% [markdown]
# ### Construção do Modelo

# %%
# Hiperparâmetros do modelo
input_dim = X_treino.shape[1]
encoding_dim = 5
input_layer = Input(shape = (input_dim, ))

# %% [markdown]
# input_layer --> encoder --> decoder

# %%
# Modelo

# Encoder
encoder = Dense(encoding_dim, activation = "tanh", activity_regularizer = regularizers.l1(10e-5))(input_layer)
encoder = Dense(int(encoding_dim / 2), activation = "relu")(encoder)

# Decoder
decoder = Dense(int(encoding_dim / 2), activation = 'tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)

# Modelo final
autoencoder = Model(inputs = input_layer, outputs = decoder)
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 10)]              0
# _________________________________________________________________
# dense (Dense)                (None, 5)                 55
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 12
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 6
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                30
# =================================================================
# Total params: 103
# Trainable params: 103
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Hiperparâmetros de treinamento
num_epoch = 50
batch_size = 256

# %%
# Compila o modelo
autoencoder.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['accuracy'])

# %%
# Checkpoint
checkpointer = ModelCheckpoint(filepath = "modelo/modelo_autoencoder.h5", verbose = 0, save_best_only = True)

# %%
tensorboard = TensorBoard(log_dir = './logs', 
                          histogram_freq = 0, 
                          write_graph = True, 
                          write_images = True,
                          profile_batch = 100000000)

# %%
# Treinamento
history = autoencoder.fit(X_treino, 
                          X_treino,
                          epochs = num_epoch,
                          batch_size = batch_size,
                          shuffle = True,
                          validation_data = (X_teste, X_teste),
                          verbose = 1,
                          callbacks = [checkpointer, tensorboard]).history
# Out:
# Epoch 1/50
# 3347/3347 [==============================] - 3s 881us/step - loss: 1.0048 - accuracy: 0.4834 - val_loss: 0.9158 - val_accuracy: 0.4911
# Epoch 2/50
# 3347/3347 [==============================] - 3s 835us/step - loss: 0.9973 - accuracy: 0.4905 - val_loss: 0.9117 - val_accuracy: 0.5080
# Epoch 3/50
# 3347/3347 [==============================] - 3s 836us/step - loss: 0.9932 - accuracy: 0.4974 - val_loss: 0.9092 - val_accuracy: 0.5245
# Epoch 4/50
# 3347/3347 [==============================] - 3s 841us/step - loss: 0.9901 - accuracy: 0.4978 - val_loss: 0.9076 - val_accuracy: 0.5321
# Epoch 5/50
50
# 3347/3347 [==============================] - 4s 1ms/step - loss: 0.9502 - accuracy: 0.3276 - val_loss: 0.8858 - val_accuracy: 0.2851
# Epoch 27/50
# 3347/3347 [==============================] - 3s 926us/step - loss: 0.9491 - accuracy: 0.3307 - val_loss: 0.8849 - val_accuracy: 0.3311
# Epoch 28/50
# 3347/3347 [==============================] - 3s 994us/step - loss: 0.9466 - accuracy: 0.3447 - val_loss: 0.8842 - val_accuracy: 0.3926
# Epoch 29/50
# 3347/3347 [==============================] - 3s 843us/step - loss: 0.9470 - accuracy: 0.3501 - val_loss: 0.8838 - val_accuracy: 0.3822
# Epoch 30/50
# 3347/3347 [==============================] - 3s 828us/step - loss: 0.9450 - accuracy: 0.3607 - val_loss: 0.8806 - val_accuracy: 0.3902
# Epoch 31/50
# 3347/3347 [==============================] - 4s 1ms/step - loss: 0.9441 - accuracy: 0.3303 - val_loss: 0.8792 - val_accuracy: 0.2663
# Epoch 32/50
# 3347/3347 [==============================] - 5s 1ms/step - loss: 0.9434 - accuracy: 0.2889 - val_loss: 0.8841 - val_accuracy: 0.3799
# Epoch 33/50
# 3347/3347 [==============================] - 5s 1ms/step - loss: 0.9456 - accuracy: 0.3095 - val_loss: 0.8847 - val_accuracy: 0.3201
# Epoch 34/50
# 3347/3347 [==============================] - 4s 1ms/step - loss: 0.9430 - accuracy: 0.2856 - val_loss: 0.8817 - val_accuracy: 0.4245
# Epoch 35/50
# 3347/3347 [==============================] - 4s 1ms/step - loss: 0.9398 - accuracy: 0.3576 - val_loss: 0.8830 - val_accuracy: 0.4053
# Epoch 36/50
# 3347/3347 [==============================] - 5s 2ms/step - loss: 0.9393 - accuracy: 0.3239 - val_loss: 0.8825 - val_accuracy: 0.3196
# Epoch 37/50
# 3347/3347 [==============================] - 5s 1ms/step - loss: 0.9382 - accuracy: 0.2824 - val_loss: 0.8760 - val_accuracy: 0.2881
# Epoch 38/50
# 3347/3347 [==============================] - 4s 1ms/step - loss: 0.9380 - accuracy: 0.2684 - val_loss: 0.8804 - val_accuracy: 0.3967
# Epoch 39/50
# 3347/3347 [==============================] - 5s 1ms/step - loss: 0.9373 - accuracy: 0.3034 - val_loss: 0.8816 - val_accuracy: 0.0955
# Epoch 40/50
# 3347/3347 [==============================] - 5s 1ms/step - loss: 0.9361 - accuracy: 0.2936 - val_loss: 0.8825 - val_accuracy: 0.3160
# Epoch 41/50
# 3347/3347 [==============================] - 5s 1ms/step - loss: 0.9367 - accuracy: 0.2982 - val_loss: 0.8786 - val_accuracy: 0.2745
# Epoch 42/50
# 3347/3347 [==============================] - 4s 1ms/step - loss: 0.9379 - accuracy: 0.2818 - val_loss: 0.8773 - val_accuracy: 0.3229
# Epoch 43/50
# 3347/3347 [==============================] - 5s 1ms/step - loss: 0.9348 - accuracy: 0.3191 - val_loss: 0.8826 - val_accuracy: 0.2078
# Epoch 44/50
# 3347/3347 [==============================] - 5s 1ms/step - loss: 0.9334 - accuracy: 0.2979 - val_loss: 0.8824 - val_accuracy: 0.3206
# Epoch 45/50
# 3347/3347 [==============================] - 4s 1ms/step - loss: 0.9325 - accuracy: 0.2586 - val_loss: 0.8809 - val_accuracy: 0.1900
# Epoch 46/50
# 3347/3347 [==============================] - 5s 1ms/step - loss: 0.9344 - accuracy: 0.2609 - val_loss: 0.8805 - val_accuracy: 0.3074
# Epoch 47/50
# 3347/3347 [==============================] - 5s 1ms/step - loss: 0.9319 - accuracy: 0.2922 - val_loss: 0.8783 - val_accuracy: 0.2714
# Epoch 48/50
# 3347/3347 [==============================] - 5s 1ms/step - loss: 0.9302 - accuracy: 0.3243 - val_loss: 0.8786 - val_accuracy: 0.2762
# Epoch 49/50
# 3347/3347 [==============================] - 5s 1ms/step - loss: 0.9297 - accuracy: 0.2997 - val_loss: 0.8762 - val_accuracy: 0.3134
# Epoch 50/50
# 3347/3347 [==============================] - 5s 1ms/step - loss: 0.9293 - accuracy: 0.3038 - val_loss: 0.8764 - val_accuracy: 0.1575

# %% [markdown]
# ### Avaliação do Modelo

# %%
# Carrega o modelo do disco
autoencoder = load_model('modelo/modelo_autoencoder.h5')

# %%
# Plot
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Erro do Modelo')
plt.ylabel('Erro')
plt.xlabel('Número de Épocas')
plt.legend(['Treino', 'Teste'], loc = 'upper right');
plt.show()

# %%
# Previsões
previsoes = autoencoder.predict(df_pca)
previsoes
# Out:
# array([[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 5.9335232e-03],
#        [6.0918336e+00, 1.0700894e+01, 0.0000000e+00, ..., 2.2406459e+00,
#         1.3803416e+01, 0.0000000e+00],
#        [0.0000000e+00, 2.3413083e-01, 0.0000000e+00, ..., 0.0000000e+00,
#         3.3423597e-01, 3.9827585e-02],
#        ...,
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00]], dtype=float32)

# %%
# Previsões em dataframe
df_previsoes = pd.DataFrame(previsoes, columns = cols_PCA)

# %%
# Visualiza
df_previsoes.head()
# Out:
#        PCA1       PCA2  PCA3      PCA4  PCA5       PCA6      PCA7      PCA8  \
# 0  0.000000   0.000000   0.0  0.000000   0.0   0.000000  0.000000  0.000000
# 1  6.091834  10.700894   0.0  5.700944   0.0  12.435617  2.092673  2.240646
# 2  0.000000   0.234131   0.0  0.056273   0.0   0.000000  0.000000  0.000000
# 3  0.000000   0.000000   0.0  0.000000   0.0   0.000000  0.000000  0.000000
# 4  3.803794   0.000000   0.0  0.000000   0.0   4.250400  0.000000  0.376143
#
#         PCA9     PCA10
# 0   0.000000  0.005934
# 1  13.803416  0.000000
# 2   0.334236  0.039828
# 3   0.019507  0.000000
# 4   0.009423  0.000000

# %%
# Shape
df_previsoes.shape
# Out:
# (1070994, 10)

# %%
# Colunas do PCA
cols_pca = ['PCA' + str(i) for i in range(1,11)]

# %%
# Dataframe
df_autoencod = pd.DataFrame(0, index = np.arange(len(df_previsoes)), columns = cols_pca)

# %%
# Loop
for i in range(0,10):
    df_autoencod.iloc[:,i] = (df_previsoes.iloc[:,i] - df_pca_scaled_z.iloc[:,i]) ** 2

# %%
# Calcula o score 2
df_autoencod['Fraud Score 2'] = df_autoencod[cols_pca].sum(axis = 1) ** (1 / 2)

# %%
# Visualiza
df_autoencod.head()
# Out:
#         PCA1       PCA2       PCA3          PCA4        PCA5       PCA6  \
# 0   0.001990   0.007166   0.001627  2.022734e-03    0.003187   0.014521
# 1  15.357960   0.021845  30.968961  1.792675e+01    8.188489  50.073807
# 2   0.000076   0.017015   0.000018  2.998576e-07    0.000376   0.015951
# 3   0.002786   0.004690   0.009365  5.941791e-03    0.003218   0.003717
# 4  40.910658  13.451864  43.387278  4.793001e+01  319.134642   0.055744
#
#          PCA7        PCA8       PCA9      PCA10  Fraud Score 2
# 0    0.001428    0.000049   0.008715   0.004741       0.213184
# 1    2.461991    3.445587   8.370492  12.479435      12.218646
# 2    0.000752    0.003438   0.046771   0.038153       0.350072
# 3    0.007917    0.000114   0.042183   0.005890       0.292954
# 4  238.177408  153.121194  10.017259  99.665519      31.078153

# %%
# Dataframe
df_score2 = pd.merge(df_score1.iloc[:,1:], df_autoencod.iloc[:,-1], left_index = True, right_index = True)

# %%
# Visualiza
df_score2.head()
# Out:
#    RECORD        BBLE  B  BLOCK  LOT EASEMENT                  OWNER BLDGCL  \
# 0       1  1000010101  1      1  101      NaN  U S GOVT LAND & BLDGS     P7
# 1       2  1000010201  1      1  201      NaN  U S GOVT LAND & BLDGS     Z9
# 2       3  1000020001  1      2    1      NaN  DEPT OF GENERAL SERVI     Y7
# 3       4  1000020023  1      2   23      NaN  DEPARTMENT OF BUSINES     T2
# 4       5  1000030001  1      3    1      NaN   PARKS AND RECREATION     Q1
#
#   TAXCLASS  LTFRONT  LTDEPTH  EXT  STORIES      FULLVAL       AVLAND  \
# 0        4    500.0   1046.0  NaN      4.0   21400000.0    4225500.0
# 1        4     27.0    355.0  NaN      1.0  193800000.0   14310000.0
# 2        4    709.0    564.0    E      3.0  104686000.0   39008700.0
# 3        4    793.0    551.0  NaN      2.0   39200000.0   15255000.0
# 4        4    323.0   1260.0  NaN      1.0  272300000.0  121050000.0
#
#          AVTOT       EXLAND        EXTOT   EXCD1            STADDR    ZIP  \
# 0    9630000.0    4225500.0    9630000.0  4600.0  1 LIBERTY ISLAND  10004
# 1   87210000.0   14310000.0   87210000.0  4600.0    1 ELLIS ISLAND  10004
# 2   47108700.0   39008700.0   47108700.0  2191.0   MARGINAL STREET  10004
# 3   17640000.0   15255000.0   17640000.0  2191.0            PIER 6  10004
# 4  122535000.0  121050000.0  122535000.0  2231.0      BATTERY PARK  10004
#
#   EXMPTCL  BLDFRONT  BLDDEPTH      AVLAND2       AVTOT2      EXLAND2  \
# 0      X3     382.0     318.0    3775500.0    8613000.0    3775500.0
# 1      X3     382.0     318.0   11111400.0   80690400.0   11111400.0
# 2      X1     709.0     564.0   32321790.0   40179510.0   32321790.0
# 3      X1      85.0     551.0   13644000.0   15750000.0   13644000.0
# 4      X1      89.0      57.0  106348680.0  107758350.0  106348680.0
#
#         EXTOT2  EXCD2 PERIOD     YEAR VALTYPE  ind1_media_ind1_grupo_ZIP  \
# 0    8613000.0    NaN  FINAL  2010/11   AC-TR                   0.132606
# 1   80690400.0    NaN  FINAL  2010/11   AC-TR                  65.525689
# 2   40179510.0    NaN  FINAL  2010/11   AC-TR                   0.848425
# 3   15750000.0    NaN  FINAL  2010/11   AC-TR                   0.290744
# 4  107758350.0    NaN  FINAL  2010/11   AC-TR                   2.168326
#
#    ind2_media_ind2_grupo_ZIP  ind3_media_ind3_grupo_ZIP  \
# 0                   0.440920                   0.322414
# 1                   3.993003                  11.679204
# 2                   0.655239                   0.638840
# 3                   2.094845                   3.063624
# 4                 134.344249                 392.945875
#
#    ind4_media_ind4_grupo_ZIP  ind5_media_ind5_grupo_ZIP  \
# 0                   0.183988                   0.384673
# 1                  33.998569                   1.302725
# 2                   2.221515                   1.078797
# 3                   0.795061                   3.602014
# 4                   6.773371                 263.878267
#
#    ind6_media_ind6_grupo_ZIP  ind7_media_ind7_grupo_ZIP  \
# 0                   0.166388                   0.146115
# 1                   2.253945                  72.201394
# 2                   0.622170                   0.934861
# 3                   3.116060                   0.320365
# 4                 456.555954                   2.389233
#
#    ind8_media_ind8_grupo_ZIP  ind9_media_ind9_grupo_ZIP  \
# 0                   0.474799                   0.338662
# 1                   4.299811                  12.267776
# 2                   0.705585                   0.671034
# 3                   2.255805                   3.218015
# 4                 144.666800                 412.748342
#
#    ind1_media_ind1_grupo_TAXCLASS  ind2_media_ind2_grupo_TAXCLASS  \
# 0                        0.186694                        0.204512
# 1                       92.252635                        1.852077
# 2                        1.194484                        0.303920
# 3                        0.409335                        0.971653
# 4                        3.052753                       62.312985
#
#    ind3_media_ind3_grupo_TAXCLASS  ind4_media_ind4_grupo_TAXCLASS  \
# 0                        0.097932                        0.203730
# 1                        3.547528                       37.646638
# 2                        0.194046                        2.459885
# 3                        0.930568                        0.880372
# 4                      119.356295                        7.500158
#
#    ind5_media_ind5_grupo_TAXCLASS  ind6_media_ind6_grupo_TAXCLASS  \
# 0                        0.126685                        0.053077
# 1                        0.429028                        0.719000
# 2                        0.355281                        0.198470
# 3                        1.186254                        0.994011
# 4                       86.903268                      145.639640
#
#    ind7_media_ind7_grupo_TAXCLASS  ind8_media_ind8_grupo_TAXCLASS  \
# 0                        0.186558                        0.194281
# 1                       92.185622                        1.759427
# 2                        1.193616                        0.288716
# 3                        0.409037                        0.923046
# 4                        3.050536                       59.195770
#
#    ind9_media_ind9_grupo_TAXCLASS  ind1_media_ind1_grupo_B  \
# 0                        0.094752                 0.112427
# 1                        3.432329                55.554558
# 2                        0.187745                 0.719319
# 3                        0.900350                 0.246501
# 4                      115.480448                 1.838369
#
#    ind2_media_ind2_grupo_B  ind3_media_ind3_grupo_B  ind4_media_ind4_grupo_B  \
# 0                 0.317461                 0.270552                 0.224860
# 1                 2.874953                 9.800572                41.551103
# 2                 0.471770                 0.536081                 2.715008
# 3                 1.508284                 2.570832                 0.971678
# 4                96.727571               329.739454                 8.278026
#
#    ind5_media_ind5_grupo_B  ind6_media_ind6_grupo_B  ind7_media_ind7_grupo_B  \
# 0                 0.512207                 0.272549                 0.192715
# 1                 1.734632                 3.692044                95.228104
# 2                 1.436462                 1.019137                 1.233010
# 3                 4.796228                 5.104220                 0.422537
# 4               351.364636               747.855349                 3.151215
#
#    ind8_media_ind8_grupo_B  ind9_media_ind9_grupo_B  \
# 0                 0.542278                 0.439817
# 1                 4.910909                15.932063
# 2                 0.805864                 0.871467
# 3                 2.576405                 4.179211
# 4               165.227152               536.032968
#
#    ind1_media_ind1_grupo_All  ind2_media_ind2_grupo_All  \
# 0                   0.119039                   0.290093
# 1                  58.821734                   2.627102
# 2                   0.761622                   0.431099
# 3                   0.260998                   1.378254
# 4                   1.946484                  88.388624
#
#    ind3_media_ind3_grupo_All  ind4_media_ind4_grupo_All  \
# 0                   0.155256                   0.728226
# 1                   5.624045                 134.566543
# 2                   0.307629                   8.792770
# 3                   1.475269                   3.146857
# 4                 189.220556                  26.809043
#
#    ind5_media_ind5_grupo_All  ind6_media_ind6_grupo_All  \
# 0                   0.788544                   0.363666
# 1                   2.670469                   4.926343
# 2                   2.211437                   1.359848
# 3                   7.383803                   6.810629
# 4                 540.926631                 997.873441
#
#    ind7_media_ind7_grupo_All  ind8_media_ind8_grupo_All  \
# 0                   0.600587                   1.048116
# 1                 296.773816                   9.491816
# 2                   3.842618                   1.557576
# 3                   1.316816                   4.979681
# 4                   9.820611                 319.351382
#
#    ind9_media_ind9_grupo_All  Fraud Score 1  Fraud Score 2
# 0                   0.575614       0.211342       0.213184
# 1                  20.851196      21.858611      12.218646
# 2                   1.140538       0.601415       0.350072
# 3                   5.469571       0.306946       0.292954
# 4                 701.536801      32.185878      31.078153

# %% [markdown]
# ## Calculando o Score Final do Score de Fraude e Apresentando os Resultados

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rank.html
#
# https://www.mathsisfun.com/algebra/matrix-rank.html

# %% [markdown]
# O posto (português brasileiro) ou característica (português europeu) de uma matriz (em inglês, "matrix rank") é o número de linhas não-nulas da matriz, quando escrita na forma escalonada por linhas. Equivalentemente, corresponde ao número de linhas ou colunas linearmente independentes da matriz. A característica de uma matriz tem várias implicações em relação à independência linear e a dimensão de um espaço vetorial.

# %%
# Cópia do dataframe
df_fraudes = df_score2.copy()

# %%
# Calcula o Rank do Score 1
df_fraudes['Rank_Fraud Score 1'] = df_fraudes['Fraud Score 1'].rank(ascending = True, method = 'first')
df_fraudes.head()
# Out:
#    RECORD        BBLE  B  BLOCK  LOT EASEMENT                  OWNER BLDGCL  \
# 0       1  1000010101  1      1  101      NaN  U S GOVT LAND & BLDGS     P7
# 1       2  1000010201  1      1  201      NaN  U S GOVT LAND & BLDGS     Z9
# 2       3  1000020001  1      2    1      NaN  DEPT OF GENERAL SERVI     Y7
# 3       4  1000020023  1      2   23      NaN  DEPARTMENT OF BUSINES     T2
# 4       5  1000030001  1      3    1      NaN   PARKS AND RECREATION     Q1
#
#   TAXCLASS  LTFRONT  LTDEPTH  EXT  STORIES      FULLVAL       AVLAND  \
# 0        4    500.0   1046.0  NaN      4.0   21400000.0    4225500.0
# 1        4     27.0    355.0  NaN      1.0  193800000.0   14310000.0
# 2        4    709.0    564.0    E      3.0  104686000.0   39008700.0
# 3        4    793.0    551.0  NaN      2.0   39200000.0   15255000.0
# 4        4    323.0   1260.0  NaN      1.0  272300000.0  121050000.0
#
#          AVTOT       EXLAND        EXTOT   EXCD1            STADDR    ZIP  \
# 0    9630000.0    4225500.0    9630000.0  4600.0  1 LIBERTY ISLAND  10004
# 1   87210000.0   14310000.0   87210000.0  4600.0    1 ELLIS ISLAND  10004
# 2   47108700.0   39008700.0   47108700.0  2191.0   MARGINAL STREET  10004
# 3   17640000.0   15255000.0   17640000.0  2191.0            PIER 6  10004
# 4  122535000.0  121050000.0  122535000.0  2231.0      BATTERY PARK  10004
#
#   EXMPTCL  BLDFRONT  BLDDEPTH      AVLAND2       AVTOT2      EXLAND2  \
# 0      X3     382.0     318.0    3775500.0    8613000.0    3775500.0
# 1      X3     382.0     318.0   11111400.0   80690400.0   11111400.0
# 2      X1     709.0     564.0   32321790.0   40179510.0   32321790.0
# 3      X1      85.0     551.0   13644000.0   15750000.0   13644000.0
# 4      X1      89.0      57.0  106348680.0  107758350.0  106348680.0
#
#         EXTOT2  EXCD2 PERIOD     YEAR VALTYPE  ind1_media_ind1_grupo_ZIP  \
# 0    8613000.0    NaN  FINAL  2010/11   AC-TR                   0.132606
# 1   80690400.0    NaN  FINAL  2010/11   AC-TR                  65.525689
# 2   40179510.0    NaN  FINAL  2010/11   AC-TR                   0.848425
# 3   15750000.0    NaN  FINAL  2010/11   AC-TR                   0.290744
# 4  107758350.0    NaN  FINAL  2010/11   AC-TR                   2.168326
#
#    ind2_media_ind2_grupo_ZIP  ind3_media_ind3_grupo_ZIP  \
# 0                   0
ind9_media_ind9_grupo_TAXCLASS  ind1_media_ind1_grupo_B  \
# 632815                     85293.645699                 0.346562
# 565391                      4474.858915              1402.666071
# 917941                      3542.682286                 1.343846
# 132748                         0.202912               975.408177
# 1067359                        1.021688              6191.398238
#
#          ind2_media_ind2_grupo_B  ind3_media_ind3_grupo_B  \
# 632815               4297.315684              8529.211578
# 565391               6633.316452              7094.088091
# 917941                261.219163               172.820560
# 132748                  0.127946                 0.218080
# 1067359                 0.912989                 0.886437
#
#          ind4_media_ind4_grupo_B  ind5_media_ind5_grupo_B  \
# 632815                 10.918825             24947.889183
# 565391              20453.624446             55324.430177
# 917941                450.994794             16153.565176
# 132748               4446.066056                 0.470467
# 1067359              5655.171444                 0.529463
#
#          ind6_media_ind6_grupo_B  ind7_media_ind7_grupo_B  \
# 632815              45105.510052                 3.143866
# 565391              48347.475246              8402.770820
# 917941               9735.156230               338.131241
# 132748                  0.500678              1671.982921
# 1067359                 0.508231              5395.857584
#
#          ind8_media_ind8_grupo_B  ind9_media_ind9_grupo_B  \
# 632815              16116.564291             31912.758060
# 565391              33377.941861             33151.872391
# 917941              27172.689482             17935.077014
# 132748                  0.218553                 0.354517
# 1067359                 0.628206                 0.606836
#
#          ind1_media_ind1_grupo_All  ind2_media_ind2_grupo_All  \
# 632815                    0.571506                4824.821074
# 565391                  996.055534                6850.105430
# 917941                    2.216100                 293.284416
# 132748                 1032.772155                   0.116915
# 1067359                2432.105694                   0.849777
#
#          ind3_media_ind3_grupo_All  ind4_media_ind4_grupo_All  \
# 632815                10328.878197                   7.967947
# 565391                 7332.282745               13887.033346
# 917941                  209.285758                 329.110772
# 132748                    0.125145               14398.937468
# 1067359                   0.909592                2595.864783
#
#          ind5_media_ind5_grupo_All  ind6_media_ind6_grupo_All  \
# 632815                29889.494191               55138.591300
# 565391                42436.016445               39141.882967
# 917941                19353.216175               11900.603717
# 132748                    0.724285                   0.668061
# 1067359                   0.403010                   0.371726
#
#          ind7_media_ind7_grupo_All  ind8_media_ind8_grupo_All  \
# 632815                    2.883423               17432.257841
# 565391                 5025.407821               24749.685481
# 917941                  310.119810               29390.962040
# 132748                 5210.654512                   0.422420
# 1067359                1636.096590                   0.409370
#
#          ind9_media_ind9_grupo_All  Fraud Score 1  Fraud Score 2  \
# 632815                38294.402650    1024.704964    1011.068832
# 565391                27184.499848     914.747699     908.860475
# 917941                21521.582668     870.173893     866.716757
# 132748                    0.463977     866.911328     849.409795
# 1067359                   0.449643     830.451116     820.500177
#
#          Rank_Fraud Score 1  Rank_Fraud Score 2
# 632815            1070994.0           1070994.0
# 565391            1070993.0           1070993.0
# 917941            1070992.0           1070992.0
# 132748            1070991.0           1070991.0
# 1067359           1070990.0           1070990.0

# %%
# Score final
df_fraudes['Final Score'] = (df_fraudes['Fraud Score 1'] * df_fraudes['Rank_Fraud Score 1']) + (df_fraudes['Fraud Score 2'] * df_fraudes['Rank_Fraud Score 2'])

# %%
# Rank do Score Final
df_fraudes['Final Rank'] = df_fraudes['Final Score'].rank(ascending = False, method = 'first')

# %%
# Resultado
df_fraudes.sort_values('Final Rank', ascending = True).head(20)
# Out:
#           RECORD         BBLE  B  BLOCK  LOT EASEMENT                  OWNER  \
# 632815    632816   4018420001  4   1842    1      NaN     864163 REALTY, LLC
# 565391    565392   3085900700  3   8590  700      NaN   U S GOVERNMENT OWNRD
# 917941    917942   4142600001  4  14260    1      NaN   LOGAN PROPERTY, INC
# 67128    2.668500e+09  2.767500e+09  2.668500e+09  2.767500e+09  2231.0
# 750815   4.919000e+03  4.919000e+03           NaN           NaN     NaN
# 920627   9.763000e+03  7.576300e+04           NaN           NaN     NaN
# 585119   9.682200e+05  9.682200e+05           NaN           NaN     NaN
# 556608   6.075000e+07  6.120000e+07  6.075000e+07  6.120000e+07  2231.0
# 935157   2.362500e+05  4.680000e+05  2.213780e+05  4.531280e+05  5113.0
# 293329   1.156500e+08  1.217254e+08  1.156500e+08  1.217254e+08  2231.0
# 1067000  6.540100e+04  1.249100e+05           NaN           NaN     NaN
# 690832   1.035000e+08  1.089000e+08  1.035000e+08  1.089000e+08  2231.0
#
#                               STADDR    ZIP EXMPTCL  BLDFRONT  BLDDEPTH  \
# 632815                86-55 BROADWAY  11373     NaN       1.0       1.0
# 565391               FLATBUSH AVENUE  11234      X1      20.0      52.0
# 917941   154-68 BROOKVILLE BOULEVARD  11422      X4      37.5      56.0
# 132748                      BROADWAY  10025     NaN     100.0     100.0
# 1067359               20 EMILY COURT  10307     NaN      36.0      45.0
# 585117      28-10 QUEENS PLAZA SOUTH  11101      X1       1.0       1.0
# 585438               11-01 43 AVENUE  11101     NaN       1.0       1.0
# 248664               PELHAM BAY PARK  10462      X1      20.0      20.0
# 85885           JOE DIMAGGIO HIGHWAY  10025      X1       8.0       8.0
# 918203                    159 STREET      1      X1      20.0      38.0
# 565397               FLATBUSH AVENUE  11234      X1      20.0      52.0
# 67128                  1000 5 AVENUE  10028      X1      66.0      93.0
# 750815                  VLEIGH PLACE  11367     NaN      21.0      40.0
# 920627            7-06 ELVIRA AVENUE  11691     NaN       1.0       1.0
# 585119                     28 STREET  11101     NaN       1.0       1.0
# 556608           9006 SEAVIEW AVENUE  11236      X1      88.0      62.0
# 935157          224 RICHMOND TERRACE  10301     NaN       1.0       1.0
# 293329         95 PROSPECT PARK WEST  11215      X1      28.0      20.0
# 1067000            238 BEDELL AVENUE  10307     NaN       1.0       1.0
# 690832          83-98 FOREST PARKWAY  11385      X1      20.0      20.0
#
#               AVLAND2        AVTOT2       EXLAND2        EXTOT2  EXCD2 PERIOD  \
# 632815   1.201200e+06  1.201200e+06           NaN           NaN    NaN  FINAL
# 565391   8.484847e+08  8.484847e+08  8.484847e+08  8.484847e+08    NaN  FINAL
# 917941   1.644454e+09  4.501180e+09  1.644454e+09  4.501180e+09    NaN  FINAL
# 132748            NaN           NaN           NaN           NaN    NaN  FINAL
# 1067359           NaN           NaN           NaN           NaN    NaN  FINAL
# 585117   1.585494e+06  1.585494e+06           NaN           NaN    NaN  FINAL
# 585438            NaN           NaN           NaN           NaN    NaN  FINAL
# 248664   7.713000e+07  8.343000e+07  7.713000e+07  8.343000e+07    NaN  FINAL
# 85885    2.813400e+07  2.826018e+07  2.813400e+07  2.826018e+07    NaN  FINAL
# 918203   3.283920e+08  3.283920e+08  3.283920e+08  3.283920e+08    NaN  FINAL
# 565397   4.352642e+08  4.352642e+08  4.352642e+08  4.352642e+08    NaN  FINAL
# 67128    2.371005e+09  2.465055e+09  2.371005e+09  2.465055e+09    NaN  FINAL
# 750815            NaN           NaN           NaN           NaN    NaN  FINAL
# 920627            NaN           NaN           NaN           NaN    NaN  FINAL
# 585119   9.754560e+05  9.754560e+05           NaN           NaN    NaN  FINAL
# 556608   5.859000e+07  5.904000e+07  5.859000e+07  5.904000e+07    NaN  FINAL
# 935157   2.098800e+05  7.483500e+05  1.950080e+05  7.334780e+05    NaN  FINAL
# 293329   1.059345e+08  1.119196e+08  1.059345e+08  1.119196e+08    NaN  FINAL
# 1067000           NaN           NaN           NaN           NaN    NaN  FINAL
# 690832   9.702000e+07  1.024200e+08  9.702000e+07  1.024200e+08    NaN  FINAL
#
#             YEAR VALTYPE  ind1_media_ind1_grupo_ZIP  \
#